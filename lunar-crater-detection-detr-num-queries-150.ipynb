# %%
from dotenv import load_dotenv
import os
api_key = os.getenv("ROBOFLOW_API_KEY")

# %%
BATCH_SIZE = 16

# %%
NEW_NUM_QUERIES = 150

# %%
# !pip install roboflow transformers

# %%
# !pip install typing_extensions==4.15.0 torch==2.7.0 torchvision torchaudio --index-url https://download.pytorch.org/whl/cu126

# %%
from roboflow import Roboflow
rf = Roboflow(api_key=api_key)
project = rf.workspace("crater-zqpjg").project("crater-vrqmn")
version = project.version(1)
dataset = version.download("coco")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
dataset_path = "./crater-1"

# %%
import os

for split in ["train", "valid", "test"]:
    images = os.listdir(f"{dataset_path}/{split}")
    print(f"{split}: {len(images)} images")
# Out:
# train: 2490 images
# valid: 712 images
# test: 357 images

# %%
import torch
import json
import os
from torch.utils.data import Dataset, DataLoader
from PIL import Image
from transformers import AutoImageProcessor

processor = AutoImageProcessor.from_pretrained("facebook/detr-resnet-50")
# Out:
# IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.

# %%
class COCODataset(Dataset):
    def __init__(self, images_dir, annotations_file, augment=False):
        self.images_dir = images_dir
        self.augment = augment

        # Load COCO annotations JSON
        with open(annotations_file, "r") as f:
            coco = json.load(f)

        # Map image_id -> image info
        self.images = {img["id"]: img for img in coco["images"]}
        self.image_ids = list(self.images.keys())

        # Map image_id -> list of annotations
        self.annotations = {}
        for ann in coco["annotations"]:
            img_id = ann["image_id"]
            self.annotations.setdefault(img_id, []).append(ann)

        self.categories = {cat["id"]: cat["name"] for cat in coco["categories"]}

    def __len__(self):
        return len(self.image_ids)

    def __getitem__(self, idx):
        image_id = self.image_ids[idx]
        image_info = self.images[image_id]

        # Load image
        img_path = os.path.join(self.images_dir, image_info["file_name"])
        image = Image.open(img_path).convert("RGB")

        # Get annotations for this image
        anns = self.annotations.get(image_id, [])

        coco_annotations = []
        for ann in anns:
            coco_annotations.append({
                "id":          ann["id"],
                "image_id":    image_id,
                "category_id": ann["category_id"] - 1,  # 1 → 0
                "bbox":        ann["bbox"],
                "area":        ann["area"],
                "iscrowd":     ann.get("iscrowd", 0),
            })

        target = {
            "image_id":    image_id,
            "annotations": coco_annotations,
        }

        # Augmentation on PIL image before processor
        if self.augment:
            import torchvision.transforms.functional as TF
            import random
            if random.random() > 0.5:
                image = TF.hflip(image)
                # Flip boxes too: new_x = img_w - x - w
                w_img = image.width
                for ann in target["annotations"]:
                    x, y, w, h = ann["bbox"]
                    ann["bbox"] = [w_img - x - w, y, w, h]

        return image, target

# %%
train_dataset = COCODataset(
    images_dir=f"{dataset_path}/train",
    annotations_file=f"{dataset_path}/train/_annotations.coco.json",
    augment=True
)

valid_dataset = COCODataset(
    images_dir=f"{dataset_path}/valid",
    annotations_file=f"{dataset_path}/valid/_annotations.coco.json",
    augment=False
)

test_dataset = COCODataset(
    images_dir=f"{dataset_path}/test",
    annotations_file=f"{dataset_path}/test/_annotations.coco.json",
    augment=False
)

# %%
def collate_fn(batch):
    images, targets = zip(*batch)

    # Processor handles resize, normalize, padding, and pixel_mask
    encoding = processor(
        images=list(images),
        annotations=list(targets),
        return_tensors="pt"
    )
    return encoding

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True,  collate_fn=collate_fn)
valid_loader = DataLoader(valid_dataset, batch_size=BATCH_SIZE, shuffle=False, collate_fn=collate_fn)
test_loader  = DataLoader(test_dataset,  batch_size=BATCH_SIZE, shuffle=False, collate_fn=collate_fn)

# %%
batch = next(iter(train_loader))
print(f"pixel_values shape : {batch['pixel_values'].shape}")   # [B, 3, H, W]
print(f"pixel_mask shape   : {batch['pixel_mask'].shape}")     # [B, H, W]
print(f"labels[0] keys     : {batch['labels'][0].keys()}")
print(f"boxes (img 0)      : {batch['labels'][0]['boxes']}")   # normalised [cx,cy,w,h]
print(f"class_labels (img 0): {batch['labels'][0]['class_labels']}")
# Out:
# pixel_values shape : torch.Size([16, 3, 800, 800])
# pixel_mask shape   : torch.Size([16, 800, 800])
# labels[0] keys     : KeysView({'size': tensor([800, 800]), 'image_id': tensor([801]), 'class_labels': tensor([0]), 'boxes': tensor([[0.4219, 0.6550, 0.3678, 0.3678]]), 'area': tensor([86571.7422]), 'iscrowd': tensor([0]), 'orig_size': tensor([416, 416])})
# boxes (img 0)      : tensor([[0.4219, 0.6550, 0.3678, 0.3678]])
# class_labels (img 0): tensor([0])

# %%
import json

def count_object_sizes(annotations_file):
    with open(annotations_file) as f:
        coco = json.load(f)

    small, medium, large = 0, 0, 0

    for ann in coco["annotations"]:
        w, h = ann["bbox"][2], ann["bbox"][3]
        area = w * h

        if area < 32**2:
            small += 1
        elif area < 96**2:
            medium += 1
        else:
            large += 1

    total = small + medium + large

    print(f"Total objects : {total}")
    print(f"Small         : {small}  ({100*small/total:.1f}%)")
    print(f"Medium        : {medium} ({100*medium/total:.1f}%)")
    print(f"Large         : {large}  ({100*large/total:.1f}%)")

    return {"small": small, "medium": medium, "large": large, "total": total}

# %%
for split in ["train", "valid", "test"]:
    print(f"\n── {split.upper()} ──")
    count_object_sizes(f"{dataset_path}/{split}/_annotations.coco.json")
# Out:
# ── TRAIN ──
# Total objects : 4953
# Small         : 3243  (65.5%)
# Medium        : 1378 (27.8%)
# Large         : 332  (6.7%)
#
# ── VALID ──
# Total objects : 1364
# Small         : 862  (63.2%)
# Medium        : 431 (31.6%)
# Large         : 71  (5.2%)
#
# ── TEST ──
# Total objects : 731
# Small         : 467  (63.9%)
# Medium        : 219 (30.0%)
# Large         : 45  (6.2%)

# %%
from transformers import AutoModelForObjectDetection

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# DETR num_labels = actual classes only, NO background token
# Dataset has 1 class (crater), so num_labels=1
NUM_CLASSES = 1
id2label = {0: "crater"}
label2id = {"crater": 0}

model_name = "facebook/detr-resnet-50"

base_model = AutoModelForObjectDetection.from_pretrained(model_name).to(device)
base_query_weights = base_model.model.query_position_embeddings.weight.data.clone()

model = AutoModelForObjectDetection.from_pretrained(
    model_name,
    num_labels=NUM_CLASSES,
    id2label=id2label,
    label2id=label2id,
    num_queries=NEW_NUM_QUERIES,
    ignore_mismatched_sizes=True
).to(device)
# Perform Weight Surgery
with torch.no_grad():
    if NEW_NUM_QUERIES < 100:
        # Take the first N queries
        model.model.query_position_embeddings.weight.data = base_query_weights[:NEW_NUM_QUERIES]
        
    elif NEW_NUM_QUERIES > 100:
        # Repeat the queries to fill the new capacity
        repeats = NEW_NUM_QUERIES // 100
        remainder = NEW_NUM_QUERIES % 100
        
        new_weights = torch.cat([
            base_query_weights.repeat(repeats, 1), 
            base_query_weights[:remainder]
        ])
        model.model.query_position_embeddings.weight.data = new_weights
# Out:
# Using device: cuda
# Loading weights: 100%|██████████| 530/530 [00:00<00:00, 14582.95it/s]
# [transformers] DetrForObjectDetection LOAD REPORT from: facebook/detr-resnet-50
# Key                                                            | Status     |  |
# ---------------------------------------------------------------+------------+--+-
# model.backbone.model.layer4.0.downsample.1.num_batches_tracked | UNEXPECTED |  |
# model.backbone.model.layer2.0.downsample.1.num_batches_tracked | UNEXPECTED |  |
# model.backbone.model.layer1.0.downsample.1.num_batches_tracked | UNEXPECTED |  |
# model.backbone.model.layer3.0.downsample.1.num_batches_tracked | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# [transformers] You passed `num_labels=1` which is incompatible to the `id2label` map of length `91`.
# Loading weights: 100%|██████████| 530/530 [00:00<00:00, 14633.35it/s]
# [transformers] DetrForObjectDetection LOAD REPORT from: facebook/detr-resnet-50
# Key                                                            | Status     |
# ---------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------
# model.backbone.model.layer4.0.downsample.1.num_batches_tracked | UNEXPECTED |
# model.backbone.model.layer2.0.downsample.1.num_batches_tracked | UNEXPECTED |
# model.backbone.model.layer1.0.downsample.1.num_batches_tracked | UNEXPECTED |
# model.backbone.model.layer3.0.downsample.1.num_batches_tracked | UNEXPECTED |
# model.query_position_embeddings.weight                         | MISMATCH   | Reinit due to size mismatch - ckpt: torch.Size([100, 256]) vs model:torch.Size([150, 256])
# class_labels_classifier.weight                                 | MISMATCH   | Reinit due to size mismatch - ckpt: torch.Size([92, 256]) vs model:torch.Size([2, 256])
# class_labels_classifier.bias                                   | MISMATCH   | Reinit due to size mismatch - ckpt: torch.Size([92]) vs model:torch.Size([2])
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISMATCH:	ckpt weights were loaded, but they did not match the original empty weight shapes.

# %%
param_groups = [
    {"params": [p for n, p in model.named_parameters() if "backbone" in n], "lr": 1e-5},
    {"params": [p for n, p in model.named_parameters() if "backbone" not in n], "lr": 1e-4},
]

optimizer = torch.optim.AdamW(param_groups, weight_decay=1e-4)

# Cosine LR decay — works better than StepLR for transformers
lr_scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
    optimizer,
    T_max=50,   # set to NUM_EPOCHS below
    eta_min=1e-6
)

# %%
def train_one_epoch(model, optimizer, dataloader, device, epoch):
    model.train()
    total_loss = 0

    for batch_idx, batch in enumerate(dataloader):
        pixel_values = batch["pixel_values"].to(device)
        pixel_mask   = batch["pixel_mask"].to(device)
        labels       = [{k: v.to(device) for k, v in t.items()} for t in batch["labels"]]

        outputs = model(
            pixel_values=pixel_values,
            pixel_mask=pixel_mask,
            labels=labels
        )

        loss = outputs.loss
        loss_dict = outputs.loss_dict   # cls, bbox, giou components

        optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=0.1)  # standard for DETR
        optimizer.step()

        total_loss += loss.item()

        if batch_idx % 10 == 0:
            print(f"Epoch [{epoch}] Batch [{batch_idx}/{len(dataloader)}] "
                  f"Loss: {loss.item():.4f} "
                  f"(cls: {loss_dict['loss_ce'].item():.4f}, "
                  f"bbox: {loss_dict['loss_bbox'].item():.4f}, "
                  f"giou: {loss_dict['loss_giou'].item():.4f})")

    return total_loss / len(dataloader)

# %%
@torch.no_grad()
def evaluate(model, dataloader, device):
    model.eval()
    total_loss = 0

    for batch in dataloader:
        pixel_values = batch["pixel_values"].to(device)
        pixel_mask   = batch["pixel_mask"].to(device)
        labels       = [{k: v.to(device) for k, v in t.items()} for t in batch["labels"]]

        # DETR returns loss in eval mode too when labels are passed — no train() trick needed
        outputs = model(
            pixel_values=pixel_values,
            pixel_mask=pixel_mask,
            labels=labels
        )
        total_loss += outputs.loss.item()

    return total_loss / len(dataloader)

# %%
NUM_EPOCHS = 50
best_val_loss = float("inf")

for epoch in range(1, NUM_EPOCHS + 1):
    train_loss = train_one_epoch(model, optimizer, train_loader, device, epoch)
    val_loss   = evaluate(model, valid_loader, device)
    lr_scheduler.step()

    print(f"\nEpoch [{epoch}/{NUM_EPOCHS}] "
          f"Train Loss: {train_loss:.4f} | "
          f"Val Loss: {val_loss:.4f}\n")

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        torch.save(model.state_dict(), f"best_detr_nq{NEW_NUM_QUERIES}.pth")
        print(f"  ✅ Saved best model (val_loss: {val_loss:.4f})")

print("Training complete!")
# Out:
# Epoch [1] Batch [0/156] Loss: 4.1990 (cls: 0.5863, bbox: 0.3638, giou: 0.8968)
# Epoch [1] Batch [10/156] Loss: 3.2469 (cls: 0.4662, bbox: 0.1807, giou: 0.9385)
# Epoch [1] Batch [20/156] Loss: 1.2954 (cls: 0.3629, bbox: 0.0377, giou: 0.3720)
# Epoch [1] Batch [30/156] Loss: 1.6292 (cls: 0.3690, bbox: 0.0671, giou: 0.4623)
# Epoch [1] Batch [40/156] Loss: 1.4868 (cls: 0.3156, bbox: 0.0649, giou: 0.4233)
# Epoch [1] Batch [50/156] Loss: 1.3570 (cls: 0.3427, bbox: 0.0332, giou: 0.4242)
# Epoch [1] Batch [60/156] Loss: 1.1933 (cls: 0.2735, bbox: 0.0319, giou: 0.3800)
# Epoch [1] Batch [70/156] Loss: 1.2576 (cls: 0.2892, bbox: 0.0341, giou: 0.3988)
# Epoch [1] Batch [80/156] Loss: 1.3002 (cls: 0.2812, bbox: 0.0377, giou: 0.4152)
# Epoch [1] Batch [90/156] Loss: 1.2974 (cls: 0.3036, bbox: 0.0359, giou: 0.4071)
# Epoch [1] Batch [100/156] Loss: 1.2838 (cls: 0.3112, bbox: 0.0363, giou: 0.3955)
# Epoch [1] Batch [110/156] Loss: 1.1793 (cls: 0.2654, bbox: 0.0445, giou: 0.3456)
# Epoch [1] Batch [120/156] Loss: 1.2916 (cls: 0.2378, bbox: 0.0567, giou: 0.3852)
# Epoch [1] Batch [130/156] Loss: 1.2427 (cls: 0.2911, bbox: 0.0387, giou: 0.3790)
# Epoch [1] Batch [140/156] Loss: 1.2480 (cls: 0.2431, bbox: 0.0319, giou: 0.4228)
# Epoch [1] Batch [150/156] Loss: 1.1656 (cls: 0.1954, bbox: 0.0262, giou: 0.4196)
#
# Epoch [1/50] Train Loss: 1.4762 | Val Loss: 1.1754
#
#   ✅ Saved best model (val_loss: 1.1754)
# Epoch [2] Batch [0/156] Loss: 0.9992 (cls: 0.1651, bbox: 0.0308, giou: 0.3400)
# Epoch [2] Batch [10/156] Loss: 1.3166 (cls: 0.2355, bbox: 0.0345, giou: 0.4544)
# Epoch [2] Batch [20/156] Loss: 1.2816 (cls: 0.2255, bbox: 0.0575, giou: 0.3844)
# Epoch [2] Batch [30/156] Loss: 1.1871 (cls: 0.2018, bbox: 0.0355, giou: 0.4039)
# Epoch [2] Batch [40/156] Loss: 1.4199 (cls: 0.1974, bbox: 0.0620, giou: 0.4564)
# Epoch [2] Batch [50/156] Loss: 0.9260 (cls: 0.1330, bbox: 0.0227, giou: 0.3398)
# Epoch [2] Batch [60/156] Loss: 0.9464 (cls: 0.1707, bbox: 0.0273, giou: 0.3196)
# Epoch [2] Batch [70/156] Loss: 1.0447 (cls: 0.2026, bbox: 0.0339, giou: 0.3362)
# Epoch [2] Batch [80/156] Loss: 0.8695 (cls: 0.1326, bbox: 0.0268, giou: 0.3014)
# Epoch [2] Batch [90/156] Loss: 1.1884 (cls: 0.1572, bbox: 0.0340, giou: 0.4306)
# Epoch [2] Batch [100/156] Loss: 1.2643 (cls: 0.1289, bbox: 0.0556, giou: 0.4286)
# Epoch [2] Batch [110/156] Loss: 1.2122 (cls: 0.1826, bbox: 0.0367, giou: 0.4229)
# Epoch [2] Batch [120/156] Loss: 1.0609 (cls: 0.1318, bbox: 0.0270, giou: 0.3970)
# Epoch [2] Batch [130/156] Loss: 1.1145 (cls: 0.0715, bbox: 0.0496, giou: 0.3976)
# Epoch [2] Batch [140/156] Loss: 1.1705 (cls: 0.1164, bbox: 0.0484, giou: 0.4060)
# Epoch [2] Batch [150/156] Loss: 1.0726 (cls: 0.1001, bbox: 0.0318, giou: 0.4067)
#
# Epoch [2/50] Train Loss: 1.1670 | Val Loss: 1.1521
#
#   ✅ Saved best model (val_loss: 1.1521)
# Epoch [3] Batch [0/156] Loss: 1.2106 (cls: 0.1482, bbox: 0.0413, giou: 0.4280)
# Epoch [3] Batch [10/156] Loss: 1.3159 (cls: 0.1938, bbox: 0.0409, giou: 0.4589)
# Epoch [3] Batch [20/156] Loss: 1.2062 (cls: 0.2306, bbox: 0.0333, giou: 0.4046)
# Epoch [3] Batch [30/156] Loss: 0.9254 (cls: 0.1646, bbox: 0.0242, giou: 0.3200)
# Epoch [3] Batch [40/156] Loss: 1.0613 (cls: 0.1655, bbox: 0.0379, giou: 0.3531)
# Epoch [3] Batch [50/156] Loss: 1.1809 (cls: 0.2197, bbox: 0.0447, giou: 0.3688)
# Epoch [3] Batch [60/156] Loss: 0.9656 (cls: 0.1850, bbox: 0.0275, giou: 0.3215)
# Epoch [3] Batch [70/156] Loss: 0.8761 (cls: 0.1542, bbox: 0.0230, giou: 0.3034)
# Epoch [3] Batch [80/156] Loss: 1.0238 (cls: 0.1727, bbox: 0.0276, giou: 0.3566)
# Epoch [3] Batch [90/156] Loss: 0.7785 (cls: 0.1187, bbox: 0.0210, giou: 0.2775)
# Epoch [3] Batch [100/156] Loss: 0.9910 (cls: 0.1816, bbox: 0.0263, giou: 0.3389)
# Epoch [3] Batch [110/156] Loss: 0.8710 (cls: 0.0883, bbox: 0.0240, giou: 0.3314)
# Epoch [3] Batch [120/156] Loss: 1.0978 (cls: 0.1238, bbox: 0.0285, giou: 0.4158)
# Epoch [3] Batch [130/156] Loss: 0.9583 (cls: 0.1176, bbox: 0.0265, giou: 0.3542)
# Epoch [3] Batch [140/156] Loss: 0.8761 (cls: 0.0600, bbox: 0.0307, giou: 0.3314)
# Epoch [3] Batch [150/156] Loss: 1.0178 (cls: 0.1202, bbox: 0.0284, giou: 0.3779)
#
# Epoch [3/50] Train Loss: 1.0464 | Val Loss: 1.1071
#
#   ✅ Saved best model (val_loss: 1.1071)
# Epoch [4] Batch [0/156] Loss: 0.8904 (cls: 0.0833, bbox: 0.0298, giou: 0.3290)
# Epoch [4] Batch [10/156] Loss: 1.0920 (cls: 0.1797, bbox: 0.0281, giou: 0.3859)
# Epoch [4] Batch [20/156] Loss: 1.0242 (cls: 0.1106, bbox: 0.0396, giou: 0.3578)
# Epoch [4] Batch [30/156] Loss: 0.9888 (cls: 0.1145, bbox: 0.0275, giou: 0.3684)
# Epoch [4] Batch [40/156] Loss: 0.9333 (cls: 0.1489, bbox: 0.0222, giou: 0.3366)
# Epoch [4] Batch [50/156] Loss: 1.0366 (cls: 0.1340, bbox: 0.0325, giou: 0.3702)
# Epoch [4] Batch [60/156] Loss: 0.8823 (cls: 0.0923, bbox: 0.0241, giou: 0.3348)
# Epoch [4] Batch [70/156] Loss: 1.1255 (cls: 0.2012, bbox: 0.0335, giou: 0.3785)
# Epoch [4] Batch [80/156] Loss: 0.7771 (cls: 0.0865, bbox: 0.0224, giou: 0.2892)
# Epoch [4] Batch [90/156] Loss: 0.8228 (cls: 0.0881, bbox: 0.0221, giou: 0.3121)
# Epoch [4] Batch [100/156] Loss: 0.9079 (cls: 0.0949, bbox: 0.0314, giou: 0.3279)
# Epoch [4] Batch [110/156] Loss: 0.8836 (cls: 0.1272, bbox: 0.0267, giou: 0.3115)
# Epoch [4] Batch [120/156] Loss: 0.8765 (cls: 0.0996, bbox: 0.0233, giou: 0.3302)
# Epoch [4] Batch [130/156] Loss: 0.9308 (cls: 0.0869, bbox: 0.0347, giou: 0.3354)
# Epoch [4] Batch [140/156] Loss: 1.0163 (cls: 0.1242, bbox: 0.0299, giou: 0.3712)
# Epoch [4] Batch [150/156] Loss: 0.8444 (cls: 0.1477, bbox: 0.0251, giou: 0.2855)
#
# Epoch [4/50] Train Loss: 0.9708 | Val Loss: 0.9784
#
#   ✅ Saved best model (val_loss: 0.9784)
# Epoch [5] Batch [0/156] Loss: 0.9669 (cls: 0.1593, bbox: 0.0348, giou: 0.3168)
# Epoch [5] Batch [10/156] Loss: 1.0623 (cls: 0.1580, bbox: 0.0361, giou: 0.3618)
# Epoch [5] Batch [20/156] Loss: 1.2521 (cls: 0.1594, bbox: 0.0455, giou: 0.4325)
# Epoch [5] Batch [30/156] Loss: 0.9756 (cls: 0.1124, bbox: 0.0250, giou: 0.3691)
# Epoch [5] Batch [40/156] Loss: 1.0037 (cls: 0.1023, bbox: 0.0360, giou: 0.3607)
# Epoch [5] Batch [50/156] Loss: 1.0857 (cls: 0.0970, bbox: 0.0456, giou: 0.3803)
# Epoch [5] Batch [60/156] Loss: 0.8258 (cls: 0.0939, bbox: 0.0214, giou: 0.3125)
# Epoch [5] Batch [70/156] Loss: 1.0792 (cls: 0.1806, bbox: 0.0314, giou: 0.3707)
# Epoch [5] Batch [80/156] Loss: 0.8859 (cls: 0.1068, bbox: 0.0261, giou: 0.3242)
# Epoch [5] Batch [90/156] Loss: 0.9563 (cls: 0.1096, bbox: 0.0309, giou: 0.3460)
# Epoch [5] Batch [100/156] Loss: 0.7617 (cls: 0.1000, bbox: 0.0238, giou: 0.2714)
# Epoch [5] Batch [110/156] Loss: 0.7858 (cls: 0.0893, bbox: 0.0202, giou: 0.2977)
# Epoch [5] Batch [120/156] Loss: 0.9157 (cls: 0.0985, bbox: 0.0326, giou: 0.3271)
# Epoch [5] Batch [130/156] Loss: 1.0312 (cls: 0.0876, bbox: 0.0319, giou: 0.3921)
# Epoch [5] Batch [140/156] Loss: 0.9457 (cls: 0.1386, bbox: 0.0341, giou: 0.3182)
# Epoch [5] Batch [150/156] Loss: 1.2054 (cls: 0.1421, bbox: 0.0513, giou: 0.4034)
#
# Epoch [5/50] Train Loss: 0.9406 | Val Loss: 0.9592
#
#   ✅ Saved best model (val_loss: 0.9592)
# Epoch [6] Batch [0/156] Loss: 0.8908 (cls: 0.0854, bbox: 0.0290, giou: 0.3302)
# Epoch [6] Batch [10/156] Loss: 0.7984 (cls: 0.0597, bbox: 0.0220, giou: 0.3145)
# Epoch [6] Batch [20/156] Loss: 0.8585 (cls: 0.1261, bbox: 0.0251, giou: 0.3035)
# Epoch [6] Batch [30/156] Loss: 0.9163 (cls: 0.0839, bbox: 0.0365, giou: 0.3250)
# Epoch [6] Batch [40/156] Loss: 0.7866 (cls: 0.0890, bbox: 0.0224, giou: 0.2928)
# Epoch [6] Batch [50/156] Loss: 1.0190 (cls: 0.0929, bbox: 0.0294, giou: 0.3895)
# Epoch [6] Batch [60/156] Loss: 1.1187 (cls: 0.1491, bbox: 0.0306, giou: 0.4082)
# Epoch [6] Batch [70/156] Loss: 0.8663 (cls: 0.1028, bbox: 0.0280, giou: 0.3118)
# Epoch [6] Batch [80/156] Loss: 1.1116 (cls: 0.0698, bbox: 0.0359, giou: 0.4312)
# Epoch [6] Batch [90/156] Loss: 0.8196 (cls: 0.0734, bbox: 0.0226, giou: 0.3166)
# Epoch [6] Batch [100/156] Loss: 0.9504 (cls: 0.0888, bbox: 0.0325, giou: 0.3495)
# Epoch [6] Batch [110/156] Loss: 0.9618 (cls: 0.0901, bbox: 0.0315, giou: 0.3570)
# Epoch [6] Batch [120/156] Loss: 1.0131 (cls: 0.1079, bbox: 0.0362, giou: 0.3621)
# Epoch [6] Batch [130/156] Loss: 1.4988 (cls: 0.2376, bbox: 0.0561, giou: 0.4905)
# Epoch [6] Batch [140/156] Loss: 1.1611 (cls: 0.1200, bbox: 0.0381, giou: 0.4252)
# Epoch [6] Batch [150/156] Loss: 0.8742 (cls: 0.0917, bbox: 0.0277, giou: 0.3221)
#
# Epoch [6/50] Train Loss: 0.9733 | Val Loss: 0.9368
#
#   ✅ Saved best model (val_loss: 0.9368)
# Epoch [7] Batch [0/156] Loss: 1.1081 (cls: 0.1337, bbox: 0.0358, giou: 0.3977)
# Epoch [7] Batch [10/156] Loss: 0.9624 (cls: 0.0930, bbox: 0.0330, giou: 0.3521)
# Epoch [7] Batch [20/156] Loss: 0.9724 (cls: 0.1126, bbox: 0.0320, giou: 0.3499)
# Epoch [7] Batch [30/156] Loss: 0.9488 (cls: 0.0610, bbox: 0.0316, giou: 0.3649)
# Epoch [7] Batch [40/156] Loss: 0.6732 (cls: 0.0535, bbox: 0.0197, giou: 0.2607)
# Epoch [7] Batch [50/156] Loss: 0.8671 (cls: 0.1056, bbox: 0.0258, giou: 0.3163)
# Epoch [7] Batch [60/156] Loss: 0.6618 (cls: 0.0652, bbox: 0.0178, giou: 0.2539)
# Epoch [7] Batch [70/156] Loss: 1.1290 (cls: 0.0933, bbox: 0.0349, giou: 0.4307)
# Epoch [7] Batch [80/156] Loss: 0.9126 (cls: 0.0619, bbox: 0.0248, giou: 0.3634)
# Epoch [7] Batch [90/156] Loss: 0.9121 (cls: 0.0646, bbox: 0.0251, giou: 0.3609)
# Epoch [7] Batch [100/156] Loss: 0.7925 (cls: 0.0977, bbox: 0.0229, giou: 0.2900)
# Epoch [7] Batch [110/156] Loss: 0.8916 (cls: 0.1255, bbox: 0.0202, giou: 0.3325)
# Epoch [7] Batch [120/156] Loss: 0.9702 (cls: 0.0936, bbox: 0.0319, giou: 0.3585)
# Epoch [7] Batch [130/156] Loss: 0.9430 (cls: 0.0977, bbox: 0.0239, giou: 0.3630)
# Epoch [7] Batch [140/156] Loss: 0.9436 (cls: 0.0903, bbox: 0.0322, giou: 0.3463)
# Epoch [7] Batch [150/156] Loss: 1.1213 (cls: 0.1250, bbox: 0.0531, giou: 0.3655)
#
# Epoch [7/50] Train Loss: 0.9373 | Val Loss: 1.2358
#
# Epoch [8] Batch [0/156] Loss: 1.0965 (cls: 0.1128, bbox: 0.0312, giou: 0.4139)
# Epoch [8] Batch [10/156] Loss: 1.0667 (cls: 0.1523, bbox: 0.0299, giou: 0.3825)
# Epoch [8] Batch [20/156] Loss: 1.2029 (cls: 0.1339, bbox: 0.0483, giou: 0.4139)
# Epoch [8] Batch [30/156] Loss: 1.5926 (cls: 0.2116, bbox: 0.0819, giou: 0.4857)
# Epoch [8] Batch [40/156] Loss: 1.6583 (cls: 0.1552, bbox: 0.1001, giou: 0.5014)
# Epoch [8] Batch [50/156] Loss: 1.7903 (cls: 0.1675, bbox: 0.0990, giou: 0.5639)
# Epoch [8] Batch [60/156] Loss: 1.1388 (cls: 0.1517, bbox: 0.0442, giou: 0.3831)
# Epoch [8] Batch [70/156] Loss: 0.7325 (cls: 0.0972, bbox: 0.0238, giou: 0.2582)
# Epoch [8] Batch [80/156] Loss: 0.9958 (cls: 0.1310, bbox: 0.0388, giou: 0.3354)
# Epoch [8] Batch [90/156] Loss: 0.9661 (cls: 0.1238, bbox: 0.0293, giou: 0.3478)
# Epoch [8] Batch [100/156] Loss: 0.9719 (cls: 0.1085, bbox: 0.0390, giou: 0.3342)
# Epoch [8] Batch [110/156] Loss: 0.7650 (cls: 0.0947, bbox: 0.0211, giou: 0.2823)
# Epoch [8] Batch [120/156] Loss: 0.8844 (cls: 0.0819, bbox: 0.0237, giou: 0.3421)
# Epoch [8] Batch [130/156] Loss: 1.0934 (cls: 0.1305, bbox: 0.0497, giou: 0.3571)
# Epoch [8] Batch [140/156] Loss: 0.9306 (cls: 0.1248, bbox: 0.0249, giou: 0.3405)
# Epoch [8] Batch [150/156] Loss: 0.8476 (cls: 0.1203, bbox: 0.0221, giou: 0.3084)
#
# Epoch [8/50] Train Loss: 1.1781 | Val Loss: 1.0279
#
# Epoch [9] Batch [0/156] Loss: 0.8669 (cls: 0.0908, bbox: 0.0275, giou: 0.3193)
# Epoch [9] Batch [10/156] Loss: 0.9747 (cls: 0.1288, bbox: 0.0366, giou: 0.3314)
# Epoch [9] Batch [20/156] Loss: 1.0771 (cls: 0.1189, bbox: 0.0313, giou: 0.4008)
# Epoch [9] Batch [30/156] Loss: 0.8838 (cls: 0.1394, bbox: 0.0230, giou: 0.3148)
# Epoch [9] Batch [40/156] Loss: 0.8576 (cls: 0.1063, bbox: 0.0197, giou: 0.3263)
# Epoch [9] Batch [50/156] Loss: 0.8810 (cls: 0.0744, bbox: 0.0280, giou: 0.3333)
# Epoch [9] Batch [60/156] Loss: 1.0196 (cls: 0.0753, bbox: 0.0273, giou: 0.4038)
# Epoch [9] Batch [70/156] Loss: 0.9440 (cls: 0.0556, bbox: 0.0315, giou: 0.3654)
# Epoch [9] Batch [80/156] Loss: 1.0289 (cls: 0.0821, bbox: 0.0546, giou: 0.3369)
# Epoch [9] Batch [90/156] Loss: 0.8313 (cls: 0.0529, bbox: 0.0266, giou: 0.3228)
# Epoch [9] Batch [100/156] Loss: 0.7533 (cls: 0.0574, bbox: 0.0212, giou: 0.2949)
# Epoch [9] Batch [110/156] Loss: 0.8560 (cls: 0.0780, bbox: 0.0224, giou: 0.3330)
# Epoch [9] Batch [120/156] Loss: 0.8762 (cls: 0.0665, bbox: 0.0218, giou: 0.3503)
# Epoch [9] Batch [130/156] Loss: 0.9564 (cls: 0.0982, bbox: 0.0353, giou: 0.3407)
# Epoch [9] Batch [140/156] Loss: 0.9012 (cls: 0.0658, bbox: 0.0374, giou: 0.3241)
# Epoch [9] Batch [150/156] Loss: 1.0951 (cls: 0.0751, bbox: 0.0359, giou: 0.4202)
#
# Epoch [9/50] Train Loss: 0.9456 | Val Loss: 0.9464
#
# Epoch [10] Batch [0/156] Loss: 0.8025 (cls: 0.1257, bbox: 0.0186, giou: 0.2918)
# Epoch [10] Batch [10/156] Loss: 0.8647 (cls: 0.0779, bbox: 0.0284, giou: 0.3224)
# Epoch [10] Batch [20/156] Loss: 1.1111 (cls: 0.1650, bbox: 0.0659, giou: 0.3083)
# Epoch [10] Batch [30/156] Loss: 1.1263 (cls: 0.1057, bbox: 0.0409, giou: 0.4080)
# Epoch [10] Batch [40/156] Loss: 0.7627 (cls: 0.0723, bbox: 0.0204, giou: 0.2942)
# Epoch [10] Batch [50/156] Loss: 0.7456 (cls: 0.0686, bbox: 0.0293, giou: 0.2652)
# Epoch [10] Batch [60/156] Loss: 1.4940 (cls: 0.1876, bbox: 0.0568, giou: 0.5111)
# Epoch [10] Batch [70/156] Loss: 1.0543 (cls: 0.1305, bbox: 0.0460, giou: 0.3469)
# Epoch [10] Batch [80/156] Loss: 0.9138 (cls: 0.1064, bbox: 0.0277, giou: 0.3343)
# Epoch [10] Batch [90/156] Loss: 1.0033 (cls: 0.1095, bbox: 0.0267, giou: 0.3801)
# Epoch [10] Batch [100/156] Loss: 0.8742 (cls: 0.0641, bbox: 0.0291, giou: 0.3322)
# Epoch [10] Batch [110/156] Loss: 1.0403 (cls: 0.1411, bbox: 0.0303, giou: 0.3738)
# Epoch [10] Batch [120/156] Loss: 0.9865 (cls: 0.1383, bbox: 0.0322, giou: 0.3435)
# Epoch [10] Batch [130/156] Loss: 1.1349 (cls: 0.1286, bbox: 0.0490, giou: 0.3807)
# Epoch [10] Batch [140/156] Loss: 0.7663 (cls: 0.0885, bbox: 0.0227, giou: 0.2822)
# Epoch [10] Batch [150/156] Loss: 0.7818 (cls: 0.0847, bbox: 0.0226, giou: 0.2921)
#
# Epoch [10/50] Train Loss: 0.9381 | Val Loss: 0.8895
#
#   ✅ Saved best model (val_loss: 0.8895)
# Epoch [11] Batch [0/156] Loss: 0.9644 (cls: 0.1122, bbox: 0.0362, giou: 0.3357)
# Epoch [11] Batch [10/156] Loss: 0.8479 (cls: 0.1057, bbox: 0.0248, giou: 0.3091)
# Epoch [11] Batch [20/156] Loss: 0.8936 (cls: 0.1529, bbox: 0.0257, giou: 0.3062)
# Epoch [11] Batch [30/156] Loss: 1.0272 (cls: 0.1210, bbox: 0.0369, giou: 0.3610)
# Epoch [11] Batch [40/156] Loss: 1.0301 (cls: 0.0824, bbox: 0.0398, giou: 0.3745)
# Epoch [11] Batch [50/156] Loss: 0.8200 (cls: 0.1180, bbox: 0.0210, giou: 0.2986)
# Epoch [11] Batch [60/156] Loss: 0.7973 (cls: 0.1115, bbox: 0.0238, giou: 0.2833)
# Epoch [11] Batch [70/156] Loss: 1.0221 (cls: 0.0925, bbox: 0.0297, giou: 0.3905)
# Epoch [11] Batch [80/156] Loss: 0.8314 (cls: 0.1038, bbox: 0.0263, giou: 0.2981)
# Epoch [11] Batch [90/156] Loss: 0.7154 (cls: 0.0488, bbox: 0.0263, giou: 0.2675)
# Epoch [11] Batch [100/156] Loss: 0.9205 (cls: 0.1150, bbox: 0.0264, giou: 0.3367)
# Epoch [11] Batch [110/156] Loss: 0.8531 (cls: 0.1246, bbox: 0.0238, giou: 0.3047)
# Epoch [11] Batch [120/156] Loss: 0.8557 (cls: 0.1087, bbox: 0.0291, giou: 0.3007)
# Epoch [11] Batch [130/156] Loss: 0.8791 (cls: 0.0993, bbox: 0.0214, giou: 0.3364)
# Epoch [11] Batch [140/156] Loss: 0.7406 (cls: 0.0611, bbox: 0.0193, giou: 0.2914)
# Epoch [11] Batch [150/156] Loss: 0.7460 (cls: 0.1231, bbox: 0.0221, giou: 0.2561)
#
# Epoch [11/50] Train Loss: 0.8732 | Val Loss: 0.9363
#
# Epoch [12] Batch [0/156] Loss: 1.0089 (cls: 0.1019, bbox: 0.0241, giou: 0.3931)
# Epoch [12] Batch [10/156] Loss: 0.8529 (cls: 0.1046, bbox: 0.0235, giou: 0.3155)
# Epoch [12] Batch [20/156] Loss: 0.7525 (cls: 0.1406, bbox: 0.0242, giou: 0.2455)
# Epoch [12] Batch [30/156] Loss: 0.8249 (cls: 0.0472, bbox: 0.0254, giou: 0.3253)
# Epoch [12] Batch [40/156] Loss: 0.8260 (cls: 0.1211, bbox: 0.0216, giou: 0.2983)
# Epoch [12] Batch [50/156] Loss: 0.8787 (cls: 0.0880, bbox: 0.0248, giou: 0.3334)
# Epoch [12] Batch [60/156] Loss: 0.8197 (cls: 0.0540, bbox: 0.0240, giou: 0.3227)
# Epoch [12] Batch [70/156] Loss: 0.7699 (cls: 0.0525, bbox: 0.0208, giou: 0.3065)
# Epoch [12] Batch [80/156] Loss: 1.0029 (cls: 0.1244, bbox: 0.0367, giou: 0.3474)
# Epoch [12] Batch [90/156] Loss: 0.9934 (cls: 0.0409, bbox: 0.0348, giou: 0.3894)
# Epoch [12] Batch [100/156] Loss: 0.8885 (cls: 0.1032, bbox: 0.0244, giou: 0.3317)
# Epoch [12] Batch [110/156] Loss: 0.9811 (cls: 0.0799, bbox: 0.0264, giou: 0.3846)
# Epoch [12] Batch [120/156] Loss: 0.7818 (cls: 0.0528, bbox: 0.0210, giou: 0.3121)
# Epoch [12] Batch [130/156] Loss: 1.1105 (cls: 0.1720, bbox: 0.0349, giou: 0.3819)
# Epoch [12] Batch [140/156] Loss: 0.8564 (cls: 0.1015, bbox: 0.0247, giou: 0.3156)
# Epoch [12] Batch [150/156] Loss: 0.8975 (cls: 0.1398, bbox: 0.0304, giou: 0.3030)
#
# Epoch [12/50] Train Loss: 0.8627 | Val Loss: 0.8429
#
#   ✅ Saved best model (val_loss: 0.8429)
# Epoch [13] Batch [0/156] Loss: 0.7249 (cls: 0.0919, bbox: 0.0219, giou: 0.2618)
# Epoch [13] Batch [10/156] Loss: 0.7854 (cls: 0.0899, bbox: 0.0299, giou: 0.2730)
# Epoch [13] Batch [20/156] Loss: 0.7782 (cls: 0.0675, bbox: 0.0216, giou: 0.3013)
# Epoch [13] Batch [30/156] Loss: 0.9106 (cls: 0.0786, bbox: 0.0207, giou: 0.3642)
# Epoch [13] Batch [40/156] Loss: 0.8845 (cls: 0.0498, bbox: 0.0254, giou: 0.3538)
# Epoch [13] Batch [50/156] Loss: 0.7797 (cls: 0.0401, bbox: 0.0277, giou: 0.3005)
# Epoch [13] Batch [60/156] Loss: 0.7808 (cls: 0.0892, bbox: 0.0236, giou: 0.2866)
# Epoch [13] Batch [70/156] Loss: 0.7679 (cls: 0.0649, bbox: 0.0209, giou: 0.2993)
# Epoch [13] Batch [80/156] Loss: 0.7803 (cls: 0.0959, bbox: 0.0225, giou: 0.2859)
# Epoch [13] Batch [90/156] Loss: 0.9251 (cls: 0.0908, bbox: 0.0254, giou: 0.3536)
# Epoch [13] Batch [100/156] Loss: 0.9269 (cls: 0.0649, bbox: 0.0264, giou: 0.3651)
# Epoch [13] Batch [110/156] Loss: 0.8377 (cls: 0.0355, bbox: 0.0258, giou: 0.3367)
# Epoch [13] Batch [120/156] Loss: 0.9377 (cls: 0.0499, bbox: 0.0284, giou: 0.3730)
# Epoch [13] Batch [130/156] Loss: 0.7820 (cls: 0.0697, bbox: 0.0249, giou: 0.2939)
# Epoch [13] Batch [140/156] Loss: 0.8848 (cls: 0.0668, bbox: 0.0216, giou: 0.3549)
# Epoch [13] Batch [150/156] Loss: 0.8077 (cls: 0.0586, bbox: 0.0289, giou: 0.3024)
#
# Epoch [13/50] Train Loss: 0.8378 | Val Loss: 0.8716
#
# Epoch [14] Batch [0/156] Loss: 0.8894 (cls: 0.0986, bbox: 0.0239, giou: 0.3356)
# Epoch [14] Batch [10/156] Loss: 0.8739 (cls: 0.1050, bbox: 0.0236, giou: 0.3256)
# Epoch [14] Batch [20/156] Loss: 0.9590 (cls: 0.1001, bbox: 0.0320, giou: 0.3495)
# Epoch [14] Batch [30/156] Loss: 0.8043 (cls: 0.0606, bbox: 0.0295, giou: 0.2980)
# Epoch [14] Batch [40/156] Loss: 0.8367 (cls: 0.0929, bbox: 0.0272, giou: 0.3038)
# Epoch [14] Batch [50/156] Loss: 0.9597 (cls: 0.0639, bbox: 0.0263, giou: 0.3822)
# Epoch [14] Batch [60/156] Loss: 0.9154 (cls: 0.0771, bbox: 0.0265, giou: 0.3530)
# Epoch [14] Batch [70/156] Loss: 0.7304 (cls: 0.0358, bbox: 0.0198, giou: 0.2978)
# Epoch [14] Batch [80/156] Loss: 0.7240 (cls: 0.0321, bbox: 0.0195, giou: 0.2972)
# Epoch [14] Batch [90/156] Loss: 0.7821 (cls: 0.0597, bbox: 0.0267, giou: 0.2943)
# Epoch [14] Batch [100/156] Loss: 0.7350 (cls: 0.0817, bbox: 0.0211, giou: 0.2740)
# Epoch [14] Batch [110/156] Loss: 0.7055 (cls: 0.0415, bbox: 0.0183, giou: 0.2864)
# Epoch [14] Batch [120/156] Loss: 0.7506 (cls: 0.1078, bbox: 0.0205, giou: 0.2702)
# Epoch [14] Batch [130/156] Loss: 0.8629 (cls: 0.1258, bbox: 0.0345, giou: 0.2824)
# Epoch [14] Batch [140/156] Loss: 0.8664 (cls: 0.1004, bbox: 0.0396, giou: 0.2839)
# Epoch [14] Batch [150/156] Loss: 0.8347 (cls: 0.0519, bbox: 0.0287, giou: 0.3197)
#
# Epoch [14/50] Train Loss: 0.8228 | Val Loss: 0.8484
#
# Epoch [15] Batch [0/156] Loss: 0.8303 (cls: 0.0387, bbox: 0.0275, giou: 0.3271)
# Epoch [15] Batch [10/156] Loss: 0.7745 (cls: 0.0563, bbox: 0.0190, giou: 0.3115)
# Epoch [15] Batch [20/156] Loss: 0.8568 (cls: 0.1019, bbox: 0.0232, giou: 0.3196)
# Epoch [15] Batch [30/156] Loss: 0.9554 (cls: 0.0834, bbox: 0.0272, giou: 0.3681)
# Epoch [15] Batch [40/156] Loss: 0.6960 (cls: 0.0418, bbox: 0.0257, giou: 0.2629)
# Epoch [15] Batch [50/156] Loss: 0.8127 (cls: 0.0491, bbox: 0.0192, giou: 0.3339)
# Epoch [15] Batch [60/156] Loss: 0.9267 (cls: 0.1182, bbox: 0.0326, giou: 0.3227)
# Epoch [15] Batch [70/156] Loss: 0.7227 (cls: 0.0467, bbox: 0.0215, giou: 0.2841)
# Epoch [15] Batch [80/156] Loss: 0.9543 (cls: 0.0484, bbox: 0.0307, giou: 0.3762)
# Epoch [15] Batch [90/156] Loss: 0.8637 (cls: 0.0597, bbox: 0.0323, giou: 0.3212)
# Epoch [15] Batch [100/156] Loss: 0.8844 (cls: 0.0728, bbox: 0.0297, giou: 0.3316)
# Epoch [15] Batch [110/156] Loss: 0.8490 (cls: 0.0558, bbox: 0.0236, giou: 0.3376)
# Epoch [15] Batch [120/156] Loss: 0.7878 (cls: 0.0732, bbox: 0.0223, giou: 0.3015)
# Epoch [15] Batch [130/156] Loss: 0.8872 (cls: 0.0916, bbox: 0.0236, giou: 0.3388)
# Epoch [15] Batch [140/156] Loss: 0.8131 (cls: 0.1037, bbox: 0.0287, giou: 0.2829)
# Epoch [15] Batch [150/156] Loss: 0.8335 (cls: 0.0255, bbox: 0.0194, giou: 0.3556)
#
# Epoch [15/50] Train Loss: 0.8013 | Val Loss: 0.8312
#
#   ✅ Saved best model (val_loss: 0.8312)
# Epoch [16] Batch [0/156] Loss: 0.8165 (cls: 0.0629, bbox: 0.0224, giou: 0.3209)
# Epoch [16] Batch [10/156] Loss: 0.7058 (cls: 0.0307, bbox: 0.0177, giou: 0.2932)
# Epoch [16] Batch [20/156] Loss: 0.7799 (cls: 0.0300, bbox: 0.0238, giou: 0.3154)
# Epoch [16] Batch [30/156] Loss: 0.8476 (cls: 0.0733, bbox: 0.0254, giou: 0.3238)
# Epoch [16] Batch [40/156] Loss: 0.7821 (cls: 0.0314, bbox: 0.0210, giou: 0.3229)
# Epoch [16] Batch [50/156] Loss: 0.8751 (cls: 0.0882, bbox: 0.0275, giou: 0.3247)
# Epoch [16] Batch [60/156] Loss: 0.7222 (cls: 0.0887, bbox: 0.0249, giou: 0.2544)
# Epoch [16] Batch [70/156] Loss: 0.7507 (cls: 0.0676, bbox: 0.0225, giou: 0.2853)
# Epoch [16] Batch [80/156] Loss: 0.9139 (cls: 0.0500, bbox: 0.0239, giou: 0.3722)
# Epoch [16] Batch [90/156] Loss: 0.8945 (cls: 0.0766, bbox: 0.0352, giou: 0.3210)
# Epoch [16] Batch [100/156] Loss: 0.7533 (cls: 0.0570, bbox: 0.0281, giou: 0.2778)
# Epoch [16] Batch [110/156] Loss: 0.6870 (cls: 0.0578, bbox: 0.0218, giou: 0.2600)
# Epoch [16] Batch [120/156] Loss: 0.7390 (cls: 0.0609, bbox: 0.0226, giou: 0.2826)
# Epoch [16] Batch [130/156] Loss: 0.7709 (cls: 0.0696, bbox: 0.0311, giou: 0.2730)
# Epoch [16] Batch [140/156] Loss: 0.7437 (cls: 0.0673, bbox: 0.0219, giou: 0.2834)
# Epoch [16] Batch [150/156] Loss: 0.8408 (cls: 0.0606, bbox: 0.0219, giou: 0.3354)
#
# Epoch [16/50] Train Loss: 0.8181 | Val Loss: 0.8359
#
# Epoch [17] Batch [0/156] Loss: 0.9138 (cls: 0.1138, bbox: 0.0315, giou: 0.3212)
# Epoch [17] Batch [10/156] Loss: 0.9572 (cls: 0.1197, bbox: 0.0242, giou: 0.3583)
# Epoch [17] Batch [20/156] Loss: 0.8724 (cls: 0.0248, bbox: 0.0312, giou: 0.3457)
# Epoch [17] Batch [30/156] Loss: 0.9833 (cls: 0.0865, bbox: 0.0292, giou: 0.3753)
# Epoch [17] Batch [40/156] Loss: 0.8489 (cls: 0.0885, bbox: 0.0243, giou: 0.3194)
# Epoch [17] Batch [50/156] Loss: 0.8693 (cls: 0.0519, bbox: 0.0211, giou: 0.3559)
# Epoch [17] Batch [60/156] Loss: 0.7895 (cls: 0.0699, bbox: 0.0212, giou: 0.3067)
# Epoch [17] Batch [70/156] Loss: 0.8334 (cls: 0.0617, bbox: 0.0241, giou: 0.3255)
# Epoch [17] Batch [80/156] Loss: 0.7792 (cls: 0.0501, bbox: 0.0199, giou: 0.3149)
# Epoch [17] Batch [90/156] Loss: 0.8157 (cls: 0.0654, bbox: 0.0359, giou: 0.2853)
# Epoch [17] Batch [100/156] Loss: 0.9006 (cls: 0.0797, bbox: 0.0350, giou: 0.3229)
# Epoch [17] Batch [110/156] Loss: 0.9084 (cls: 0.0962, bbox: 0.0313, giou: 0.3280)
# Epoch [17] Batch [120/156] Loss: 0.8250 (cls: 0.0585, bbox: 0.0390, giou: 0.2858)
# Epoch [17] Batch [130/156] Loss: 0.9098 (cls: 0.0571, bbox: 0.0258, giou: 0.3618)
# Epoch [17] Batch [140/156] Loss: 0.7463 (cls: 0.0568, bbox: 0.0201, giou: 0.2945)
# Epoch [17] Batch [150/156] Loss: 0.9376 (cls: 0.0678, bbox: 0.0280, giou: 0.3650)
#
# Epoch [17/50] Train Loss: 0.8375 | Val Loss: 0.8465
#
# Epoch [18] Batch [0/156] Loss: 0.6741 (cls: 0.0363, bbox: 0.0173, giou: 0.2756)
# Epoch [18] Batch [10/156] Loss: 0.6856 (cls: 0.0448, bbox: 0.0192, giou: 0.2723)
# Epoch [18] Batch [20/156] Loss: 0.6721 (cls: 0.0504, bbox: 0.0231, giou: 0.2530)
# Epoch [18] Batch [30/156] Loss: 0.8033 (cls: 0.0337, bbox: 0.0204, giou: 0.3337)
# Epoch [18] Batch [40/156] Loss: 0.8574 (cls: 0.0635, bbox: 0.0283, giou: 0.3263)
# Epoch [18] Batch [50/156] Loss: 0.6969 (cls: 0.0428, bbox: 0.0179, giou: 0.2823)
# Epoch [18] Batch [60/156] Loss: 0.8171 (cls: 0.0379, bbox: 0.0243, giou: 0.3290)
# Epoch [18] Batch [70/156] Loss: 0.7426 (cls: 0.0724, bbox: 0.0281, giou: 0.2649)
# Epoch [18] Batch [80/156] Loss: 0.8555 (cls: 0.0770, bbox: 0.0290, giou: 0.3169)
# Epoch [18] Batch [90/156] Loss: 0.7845 (cls: 0.0696, bbox: 0.0207, giou: 0.3057)
# Epoch [18] Batch [100/156] Loss: 0.7360 (cls: 0.0808, bbox: 0.0226, giou: 0.2710)
# Epoch [18] Batch [110/156] Loss: 0.8106 (cls: 0.0515, bbox: 0.0205, giou: 0.3282)
# Epoch [18] Batch [120/156] Loss: 0.9233 (cls: 0.0599, bbox: 0.0300, giou: 0.3567)
# Epoch [18] Batch [130/156] Loss: 0.7139 (cls: 0.0595, bbox: 0.0188, giou: 0.2803)
# Epoch [18] Batch [140/156] Loss: 0.9888 (cls: 0.0730, bbox: 0.0337, giou: 0.3736)
# Epoch [18] Batch [150/156] Loss: 0.7781 (cls: 0.0629, bbox: 0.0256, giou: 0.2937)
#
# Epoch [18/50] Train Loss: 0.8229 | Val Loss: 0.9085
#
# Epoch [19] Batch [0/156] Loss: 0.7446 (cls: 0.0500, bbox: 0.0242, giou: 0.2869)
# Epoch [19] Batch [10/156] Loss: 0.7075 (cls: 0.0427, bbox: 0.0251, giou: 0.2697)
# Epoch [19] Batch [20/156] Loss: 0.9686 (cls: 0.0802, bbox: 0.0338, giou: 0.3596)
# Epoch [19] Batch [30/156] Loss: 0.7385 (cls: 0.0552, bbox: 0.0203, giou: 0.2909)
# Epoch [19] Batch [40/156] Loss: 0.6607 (cls: 0.0188, bbox: 0.0216, giou: 0.2669)
# Epoch [19] Batch [50/156] Loss: 0.6490 (cls: 0.0598, bbox: 0.0210, giou: 0.2421)
# Epoch [19] Batch [60/156] Loss: 0.8696 (cls: 0.0520, bbox: 0.0251, giou: 0.3461)
# Epoch [19] Batch [70/156] Loss: 1.0647 (cls: 0.0612, bbox: 0.0316, giou: 0.4227)
# Epoch [19] Batch [80/156] Loss: 0.7267 (cls: 0.0675, bbox: 0.0221, giou: 0.2743)
# Epoch [19] Batch [90/156] Loss: 0.7741 (cls: 0.0404, bbox: 0.0193, giou: 0.3186)
# Epoch [19] Batch [100/156] Loss: 0.7262 (cls: 0.0504, bbox: 0.0189, giou: 0.2907)
# Epoch [19] Batch [110/156] Loss: 0.6957 (cls: 0.0486, bbox: 0.0206, giou: 0.2720)
# Epoch [19] Batch [120/156] Loss: 0.8708 (cls: 0.0610, bbox: 0.0283, giou: 0.3342)
# Epoch [19] Batch [130/156] Loss: 0.7736 (cls: 0.0918, bbox: 0.0191, giou: 0.2930)
# Epoch [19] Batch [140/156] Loss: 1.0536 (cls: 0.1140, bbox: 0.0374, giou: 0.3764)
# Epoch [19] Batch [150/156] Loss: 0.7607 (cls: 0.0339, bbox: 0.0219, giou: 0.3087)
#
# Epoch [19/50] Train Loss: 0.8143 | Val Loss: 0.8085
#
#   ✅ Saved best model (val_loss: 0.8085)
# Epoch [20] Batch [0/156] Loss: 0.8959 (cls: 0.0646, bbox: 0.0345, giou: 0.3293)
# Epoch [20] Batch [10/156] Loss: 0.8384 (cls: 0.0700, bbox: 0.0231, giou: 0.3265)
# Epoch [20] Batch [20/156] Loss: 0.7399 (cls: 0.0554, bbox: 0.0173, giou: 0.2989)
# Epoch [20] Batch [30/156] Loss: 0.7394 (cls: 0.0749, bbox: 0.0195, giou: 0.2835)
# Epoch [20] Batch [40/156] Loss: 0.7219 (cls: 0.0723, bbox: 0.0313, giou: 0.2465)
# Epoch [20] Batch [50/156] Loss: 0.7831 (cls: 0.0654, bbox: 0.0332, giou: 0.2758)
# Epoch [20] Batch [60/156] Loss: 0.7142 (cls: 0.0436, bbox: 0.0246, giou: 0.2737)
# Epoch [20] Batch [70/156] Loss: 0.7314 (cls: 0.0439, bbox: 0.0238, giou: 0.2842)
# Epoch [20] Batch [80/156] Loss: 0.6923 (cls: 0.0494, bbox: 0.0187, giou: 0.2746)
# Epoch [20] Batch [90/156] Loss: 0.8396 (cls: 0.0454, bbox: 0.0233, giou: 0.3389)
# Epoch [20] Batch [100/156] Loss: 0.8134 (cls: 0.0599, bbox: 0.0223, giou: 0.3208)
# Epoch [20] Batch [110/156] Loss: 0.7644 (cls: 0.0461, bbox: 0.0179, giou: 0.3143)
# Epoch [20] Batch [120/156] Loss: 0.7638 (cls: 0.0863, bbox: 0.0206, giou: 0.2873)
# Epoch [20] Batch [130/156] Loss: 0.7766 (cls: 0.0502, bbox: 0.0276, giou: 0.2943)
# Epoch [20] Batch [140/156] Loss: 0.7765 (cls: 0.0369, bbox: 0.0195, giou: 0.3211)
# Epoch [20] Batch [150/156] Loss: 0.7601 (cls: 0.0513, bbox: 0.0187, giou: 0.3077)
#
# Epoch [20/50] Train Loss: 0.7720 | Val Loss: 0.8180
#
# Epoch [21] Batch [0/156] Loss: 0.7562 (cls: 0.0576, bbox: 0.0187, giou: 0.3026)
# Epoch [21] Batch [10/156] Loss: 0.8688 (cls: 0.0517, bbox: 0.0287, giou: 0.3367)
# Epoch [21] Batch [20/156] Loss: 0.6292 (cls: 0.0350, bbox: 0.0181, giou: 0.2517)
# Epoch [21] Batch [30/156] Loss: 0.7166 (cls: 0.0908, bbox: 0.0209, giou: 0.2607)
# Epoch [21] Batch [40/156] Loss: 0.7212 (cls: 0.0508, bbox: 0.0163, giou: 0.2945)
# Epoch [21] Batch [50/156] Loss: 0.8384 (cls: 0.0497, bbox: 0.0251, giou: 0.3316)
# Epoch [21] Batch [60/156] Loss: 0.5998 (cls: 0.0347, bbox: 0.0171, giou: 0.2397)
# Epoch [21] Batch [70/156] Loss: 0.7862 (cls: 0.0674, bbox: 0.0220, giou: 0.3043)
# Epoch [21] Batch [80/156] Loss: 0.6775 (cls: 0.0620, bbox: 0.0191, giou: 0.2599)
# Epoch [21] Batch [90/156] Loss: 0.7105 (cls: 0.0958, bbox: 0.0179, giou: 0.2626)
# Epoch [21] Batch [100/156] Loss: 0.8994 (cls: 0.1314, bbox: 0.0199, giou: 0.3343)
# Epoch [21] Batch [110/156] Loss: 0.8023 (cls: 0.0401, bbox: 0.0330, giou: 0.2987)
# Epoch [21] Batch [120/156] Loss: 0.6394 (cls: 0.0375, bbox: 0.0173, giou: 0.2577)
# Epoch [21] Batch [130/156] Loss: 0.7721 (cls: 0.0716, bbox: 0.0172, giou: 0.3073)
# Epoch [21] Batch [140/156] Loss: 0.7307 (cls: 0.0630, bbox: 0.0242, giou: 0.2734)
# Epoch [21] Batch [150/156] Loss: 0.7643 (cls: 0.0757, bbox: 0.0207, giou: 0.2925)
#
# Epoch [21/50] Train Loss: 0.7603 | Val Loss: 0.8285
#
# Epoch [22] Batch [0/156] Loss: 0.9540 (cls: 0.0516, bbox: 0.0220, giou: 0.3961)
# Epoch [22] Batch [10/156] Loss: 0.6739 (cls: 0.0837, bbox: 0.0203, giou: 0.2444)
# Epoch [22] Batch [20/156] Loss: 0.8776 (cls: 0.1410, bbox: 0.0199, giou: 0.3185)
# Epoch [22] Batch [30/156] Loss: 0.7301 (cls: 0.0330, bbox: 0.0296, giou: 0.2746)
# Epoch [22] Batch [40/156] Loss: 0.7562 (cls: 0.0417, bbox: 0.0217, giou: 0.3029)
# Epoch [22] Batch [50/156] Loss: 0.7577 (cls: 0.0557, bbox: 0.0215, giou: 0.2972)
# Epoch [22] Batch [60/156] Loss: 0.6746 (cls: 0.0767, bbox: 0.0163, giou: 0.2581)
# Epoch [22] Batch [70/156] Loss: 0.7197 (cls: 0.0618, bbox: 0.0182, giou: 0.2835)
# Epoch [22] Batch [80/156] Loss: 0.8900 (cls: 0.0935, bbox: 0.0246, giou: 0.3366)
# Epoch [22] Batch [90/156] Loss: 0.7061 (cls: 0.0340, bbox: 0.0182, giou: 0.2906)
# Epoch [22] Batch [100/156] Loss: 0.7469 (cls: 0.1104, bbox: 0.0193, giou: 0.2700)
# Epoch [22] Batch [110/156] Loss: 0.9775 (cls: 0.0848, bbox: 0.0278, giou: 0.3768)
# Epoch [22] Batch [120/156] Loss: 0.8030 (cls: 0.0915, bbox: 0.0182, giou: 0.3103)
# Epoch [22] Batch [130/156] Loss: 0.7926 (cls: 0.0443, bbox: 0.0256, giou: 0.3100)
# Epoch [22] Batch [140/156] Loss: 0.8612 (cls: 0.1138, bbox: 0.0225, giou: 0.3175)
# Epoch [22] Batch [150/156] Loss: 0.6930 (cls: 0.0454, bbox: 0.0193, giou: 0.2755)
#
# Epoch [22/50] Train Loss: 0.7499 | Val Loss: 0.7797
#
#   ✅ Saved best model (val_loss: 0.7797)
# Epoch [23] Batch [0/156] Loss: 0.6038 (cls: 0.0485, bbox: 0.0214, giou: 0.2242)
# Epoch [23] Batch [10/156] Loss: 0.6353 (cls: 0.0800, bbox: 0.0221, giou: 0.2225)
# Epoch [23] Batch [20/156] Loss: 0.6447 (cls: 0.0356, bbox: 0.0196, giou: 0.2556)
# Epoch [23] Batch [30/156] Loss: 0.7788 (cls: 0.0712, bbox: 0.0201, giou: 0.3035)
# Epoch [23] Batch [40/156] Loss: 0.9650 (cls: 0.0693, bbox: 0.0313, giou: 0.3695)
# Epoch [23] Batch [50/156] Loss: 0.7831 (cls: 0.0358, bbox: 0.0181, giou: 0.3285)
# Epoch [23] Batch [60/156] Loss: 0.7424 (cls: 0.0220, bbox: 0.0169, giou: 0.3178)
# Epoch [23] Batch [70/156] Loss: 0.6737 (cls: 0.0336, bbox: 0.0176, giou: 0.2760)
# Epoch [23] Batch [80/156] Loss: 0.8426 (cls: 0.1054, bbox: 0.0231, giou: 0.3108)
# Epoch [23] Batch [90/156] Loss: 0.8032 (cls: 0.0786, bbox: 0.0199, giou: 0.3126)
# Epoch [23] Batch [100/156] Loss: 0.9980 (cls: 0.0595, bbox: 0.0313, giou: 0.3910)
# Epoch [23] Batch [110/156] Loss: 0.7331 (cls: 0.0260, bbox: 0.0165, giou: 0.3124)
# Epoch [23] Batch [120/156] Loss: 0.7153 (cls: 0.0963, bbox: 0.0203, giou: 0.2588)
# Epoch [23] Batch [130/156] Loss: 0.7876 (cls: 0.0992, bbox: 0.0224, giou: 0.2881)
# Epoch [23] Batch [140/156] Loss: 0.8033 (cls: 0.1333, bbox: 0.0205, giou: 0.2837)
# Epoch [23] Batch [150/156] Loss: 0.8350 (cls: 0.0789, bbox: 0.0256, giou: 0.3139)
#
# Epoch [23/50] Train Loss: 0.7610 | Val Loss: 0.8155
#
# Epoch [24] Batch [0/156] Loss: 0.6597 (cls: 0.0586, bbox: 0.0229, giou: 0.2433)
# Epoch [24] Batch [10/156] Loss: 0.7243 (cls: 0.0414, bbox: 0.0187, giou: 0.2946)
# Epoch [24] Batch [20/156] Loss: 0.8744 (cls: 0.0699, bbox: 0.0189, giou: 0.3550)
# Epoch [24] Batch [30/156] Loss: 0.7066 (cls: 0.0781, bbox: 0.0171, giou: 0.2715)
# Epoch [24] Batch [40/156] Loss: 0.8282 (cls: 0.0978, bbox: 0.0276, giou: 0.2961)
# Epoch [24] Batch [50/156] Loss: 0.6019 (cls: 0.0732, bbox: 0.0216, giou: 0.2103)
# Epoch [24] Batch [60/156] Loss: 0.8714 (cls: 0.1158, bbox: 0.0217, giou: 0.3237)
# Epoch [24] Batch [70/156] Loss: 0.7752 (cls: 0.1067, bbox: 0.0223, giou: 0.2785)
# Epoch [24] Batch [80/156] Loss: 0.8103 (cls: 0.1115, bbox: 0.0345, giou: 0.2632)
# Epoch [24] Batch [90/156] Loss: 0.7535 (cls: 0.0964, bbox: 0.0212, giou: 0.2756)
# Epoch [24] Batch [100/156] Loss: 0.7189 (cls: 0.0628, bbox: 0.0166, giou: 0.2866)
# Epoch [24] Batch [110/156] Loss: 0.7854 (cls: 0.0686, bbox: 0.0275, giou: 0.2898)
# Epoch [24] Batch [120/156] Loss: 0.9145 (cls: 0.0842, bbox: 0.0332, giou: 0.3322)
# Epoch [24] Batch [130/156] Loss: 0.6907 (cls: 0.0244, bbox: 0.0215, giou: 0.2794)
# Epoch [24] Batch [140/156] Loss: 0.8253 (cls: 0.0598, bbox: 0.0244, giou: 0.3217)
# Epoch [24] Batch [150/156] Loss: 0.6518 (cls: 0.0319, bbox: 0.0216, giou: 0.2559)
#
# Epoch [24/50] Train Loss: 0.7575 | Val Loss: 0.7893
#
# Epoch [25] Batch [0/156] Loss: 0.7820 (cls: 0.0776, bbox: 0.0211, giou: 0.2994)
# Epoch [25] Batch [10/156] Loss: 0.7006 (cls: 0.0201, bbox: 0.0218, giou: 0.2856)
# Epoch [25] Batch [20/156] Loss: 0.6262 (cls: 0.0301, bbox: 0.0186, giou: 0.2514)
# Epoch [25] Batch [30/156] Loss: 0.6712 (cls: 0.0335, bbox: 0.0174, giou: 0.2753)
# Epoch [25] Batch [40/156] Loss: 0.6031 (cls: 0.0403, bbox: 0.0180, giou: 0.2365)
# Epoch [25] Batch [50/156] Loss: 0.7422 (cls: 0.0678, bbox: 0.0181, giou: 0.2919)
# Epoch [25] Batch [60/156] Loss: 0.7273 (cls: 0.0284, bbox: 0.0211, giou: 0.2967)
# Epoch [25] Batch [70/156] Loss: 0.8819 (cls: 0.0945, bbox: 0.0228, giou: 0.3366)
# Epoch [25] Batch [80/156] Loss: 0.8666 (cls: 0.1007, bbox: 0.0293, giou: 0.3097)
# Epoch [25] Batch [90/156] Loss: 0.6046 (cls: 0.0357, bbox: 0.0183, giou: 0.2388)
# Epoch [25] Batch [100/156] Loss: 0.8384 (cls: 0.0555, bbox: 0.0299, giou: 0.3168)
# Epoch [25] Batch [110/156] Loss: 0.7769 (cls: 0.0671, bbox: 0.0195, giou: 0.3062)
# Epoch [25] Batch [120/156] Loss: 0.6387 (cls: 0.0680, bbox: 0.0215, giou: 0.2315)
# Epoch [25] Batch [130/156] Loss: 0.7859 (cls: 0.0678, bbox: 0.0194, giou: 0.3105)
# Epoch [25] Batch [140/156] Loss: 0.7387 (cls: 0.0366, bbox: 0.0200, giou: 0.3011)
# Epoch [25] Batch [150/156] Loss: 0.6807 (cls: 0.0677, bbox: 0.0169, giou: 0.2642)
#
# Epoch [25/50] Train Loss: 0.7321 | Val Loss: 0.7738
#
#   ✅ Saved best model (val_loss: 0.7738)
# Epoch [26] Batch [0/156] Loss: 0.7161 (cls: 0.0578, bbox: 0.0221, giou: 0.2739)
# Epoch [26] Batch [10/156] Loss: 0.6829 (cls: 0.0289, bbox: 0.0179, giou: 0.2823)
# Epoch [26] Batch [20/156] Loss: 0.6727 (cls: 0.0847, bbox: 0.0205, giou: 0.2427)
# Epoch [26] Batch [30/156] Loss: 0.7588 (cls: 0.0376, bbox: 0.0223, giou: 0.3047)
# Epoch [26] Batch [40/156] Loss: 0.7839 (cls: 0.0737, bbox: 0.0229, giou: 0.2978)
# Epoch [26] Batch [50/156] Loss: 0.7441 (cls: 0.0611, bbox: 0.0246, giou: 0.2800)
# Epoch [26] Batch [60/156] Loss: 0.7337 (cls: 0.0764, bbox: 0.0239, giou: 0.2690)
# Epoch [26] Batch [70/156] Loss: 1.0465 (cls: 0.1554, bbox: 0.0335, giou: 0.3619)
# Epoch [26] Batch [80/156] Loss: 0.7081 (cls: 0.0682, bbox: 0.0198, giou: 0.2704)
# Epoch [26] Batch [90/156] Loss: 0.7644 (cls: 0.0580, bbox: 0.0187, giou: 0.3064)
# Epoch [26] Batch [100/156] Loss: 0.5828 (cls: 0.0290, bbox: 0.0165, giou: 0.2357)
# Epoch [26] Batch [110/156] Loss: 0.8517 (cls: 0.1268, bbox: 0.0205, giou: 0.3111)
# Epoch [26] Batch [120/156] Loss: 0.7115 (cls: 0.0478, bbox: 0.0181, giou: 0.2866)
# Epoch [26] Batch [130/156] Loss: 0.7483 (cls: 0.0868, bbox: 0.0294, giou: 0.2573)
# Epoch [26] Batch [140/156] Loss: 0.6251 (cls: 0.0709, bbox: 0.0148, giou: 0.2402)
# Epoch [26] Batch [150/156] Loss: 0.5420 (cls: 0.0586, bbox: 0.0217, giou: 0.1875)
#
# Epoch [26/50] Train Loss: 0.7273 | Val Loss: 0.7546
#
#   ✅ Saved best model (val_loss: 0.7546)
# Epoch [27] Batch [0/156] Loss: 0.6293 (cls: 0.0331, bbox: 0.0165, giou: 0.2568)
# Epoch [27] Batch [10/156] Loss: 0.6233 (cls: 0.0315, bbox: 0.0155, giou: 0.2571)
# Epoch [27] Batch [20/156] Loss: 0.7630 (cls: 0.0592, bbox: 0.0191, giou: 0.3041)
# Epoch [27] Batch [30/156] Loss: 0.7087 (cls: 0.0594, bbox: 0.0198, giou: 0.2752)
# Epoch [27] Batch [40/156] Loss: 0.7363 (cls: 0.0435, bbox: 0.0227, giou: 0.2896)
# Epoch [27] Batch [50/156] Loss: 0.6567 (cls: 0.0227, bbox: 0.0191, giou: 0.2692)
# Epoch [27] Batch [60/156] Loss: 0.6756 (cls: 0.0439, bbox: 0.0207, giou: 0.2641)
# Epoch [27] Batch [70/156] Loss: 0.5680 (cls: 0.0262, bbox: 0.0153, giou: 0.2327)
# Epoch [27] Batch [80/156] Loss: 0.7220 (cls: 0.0539, bbox: 0.0268, giou: 0.2671)
# Epoch [27] Batch [90/156] Loss: 0.7731 (cls: 0.1325, bbox: 0.0148, giou: 0.2834)
# Epoch [27] Batch [100/156] Loss: 0.6458 (cls: 0.0372, bbox: 0.0285, giou: 0.2331)
# Epoch [27] Batch [110/156] Loss: 0.7721 (cls: 0.0448, bbox: 0.0224, giou: 0.3077)
# Epoch [27] Batch [120/156] Loss: 0.5190 (cls: 0.0418, bbox: 0.0128, giou: 0.2066)
# Epoch [27] Batch [130/156] Loss: 0.7224 (cls: 0.0544, bbox: 0.0182, giou: 0.2885)
# Epoch [27] Batch [140/156] Loss: 0.7661 (cls: 0.0735, bbox: 0.0173, giou: 0.3030)
# Epoch [27] Batch [150/156] Loss: 0.8216 (cls: 0.0586, bbox: 0.0286, giou: 0.3100)
#
# Epoch [27/50] Train Loss: 0.7037 | Val Loss: 0.7716
#
# Epoch [28] Batch [0/156] Loss: 0.6408 (cls: 0.0452, bbox: 0.0209, giou: 0.2454)
# Epoch [28] Batch [10/156] Loss: 0.7917 (cls: 0.0923, bbox: 0.0155, giou: 0.3110)
# Epoch [28] Batch [20/156] Loss: 0.6485 (cls: 0.0469, bbox: 0.0186, giou: 0.2542)
# Epoch [28] Batch [30/156] Loss: 0.6313 (cls: 0.0171, bbox: 0.0203, giou: 0.2564)
# Epoch [28] Batch [40/156] Loss: 0.7368 (cls: 0.0737, bbox: 0.0178, giou: 0.2869)
# Epoch [28] Batch [50/156] Loss: 0.7746 (cls: 0.0486, bbox: 0.0186, giou: 0.3165)
# Epoch [28] Batch [60/156] Loss: 0.6880 (cls: 0.0753, bbox: 0.0193, giou: 0.2582)
# Epoch [28] Batch [70/156] Loss: 0.6340 (cls: 0.0291, bbox: 0.0214, giou: 0.2488)
# Epoch [28] Batch [80/156] Loss: 0.7178 (cls: 0.0486, bbox: 0.0164, giou: 0.2935)
# Epoch [28] Batch [90/156] Loss: 0.5902 (cls: 0.0288, bbox: 0.0190, giou: 0.2332)
# Epoch [28] Batch [100/156] Loss: 0.8427 (cls: 0.0871, bbox: 0.0375, giou: 0.2840)
# Epoch [28] Batch [110/156] Loss: 0.7111 (cls: 0.0803, bbox: 0.0189, giou: 0.2681)
# Epoch [28] Batch [120/156] Loss: 0.7675 (cls: 0.0303, bbox: 0.0306, giou: 0.2922)
# Epoch [28] Batch [130/156] Loss: 0.6184 (cls: 0.0309, bbox: 0.0181, giou: 0.2486)
# Epoch [28] Batch [140/156] Loss: 0.6654 (cls: 0.0239, bbox: 0.0171, giou: 0.2779)
# Epoch [28] Batch [150/156] Loss: 0.6391 (cls: 0.0675, bbox: 0.0170, giou: 0.2432)
#
# Epoch [28/50] Train Loss: 0.7121 | Val Loss: 0.7595
#
# Epoch [29] Batch [0/156] Loss: 0.5652 (cls: 0.0320, bbox: 0.0168, giou: 0.2247)
# Epoch [29] Batch [10/156] Loss: 0.6650 (cls: 0.0168, bbox: 0.0186, giou: 0.2777)
# Epoch [29] Batch [20/156] Loss: 0.5860 (cls: 0.0124, bbox: 0.0147, giou: 0.2501)
# Epoch [29] Batch [30/156] Loss: 0.7214 (cls: 0.0355, bbox: 0.0177, giou: 0.2987)
# Epoch [29] Batch [40/156] Loss: 0.5151 (cls: 0.0480, bbox: 0.0154, giou: 0.1949)
# Epoch [29] Batch [50/156] Loss: 0.6648 (cls: 0.0195, bbox: 0.0161, giou: 0.2824)
# Epoch [29] Batch [60/156] Loss: 0.6191 (cls: 0.0359, bbox: 0.0167, giou: 0.2498)
# Epoch [29] Batch [70/156] Loss: 0.6211 (cls: 0.0494, bbox: 0.0156, giou: 0.2468)
# Epoch [29] Batch [80/156] Loss: 0.6910 (cls: 0.0862, bbox: 0.0175, giou: 0.2588)
# Epoch [29] Batch [90/156] Loss: 0.8513 (cls: 0.0476, bbox: 0.0241, giou: 0.3417)
# Epoch [29] Batch [100/156] Loss: 0.7415 (cls: 0.0707, bbox: 0.0197, giou: 0.2862)
# Epoch [29] Batch [110/156] Loss: 0.7972 (cls: 0.0735, bbox: 0.0222, giou: 0.3063)
# Epoch [29] Batch [120/156] Loss: 0.8380 (cls: 0.0332, bbox: 0.0197, giou: 0.3531)
# Epoch [29] Batch [130/156] Loss: 0.7097 (cls: 0.0363, bbox: 0.0217, giou: 0.2826)
# Epoch [29] Batch [140/156] Loss: 0.6198 (cls: 0.0672, bbox: 0.0153, giou: 0.2380)
# Epoch [29] Batch [150/156] Loss: 0.7735 (cls: 0.0681, bbox: 0.0250, giou: 0.2901)
#
# Epoch [29/50] Train Loss: 0.6967 | Val Loss: 0.7805
#
# Epoch [30] Batch [0/156] Loss: 0.8218 (cls: 0.0811, bbox: 0.0230, giou: 0.3128)
# Epoch [30] Batch [10/156] Loss: 0.6378 (cls: 0.0453, bbox: 0.0172, giou: 0.2532)
# Epoch [30] Batch [20/156] Loss: 0.7104 (cls: 0.1007, bbox: 0.0195, giou: 0.2561)
# Epoch [30] Batch [30/156] Loss: 0.7201 (cls: 0.0335, bbox: 0.0175, giou: 0.2995)
# Epoch [30] Batch [40/156] Loss: 0.5864 (cls: 0.0304, bbox: 0.0159, giou: 0.2384)
# Epoch [30] Batch [50/156] Loss: 0.6761 (cls: 0.0581, bbox: 0.0163, giou: 0.2682)
# Epoch [30] Batch [60/156] Loss: 0.6995 (cls: 0.0263, bbox: 0.0174, giou: 0.2931)
# Epoch [30] Batch [70/156] Loss: 0.5874 (cls: 0.0415, bbox: 0.0198, giou: 0.2233)
# Epoch [30] Batch [80/156] Loss: 0.7824 (cls: 0.0755, bbox: 0.0170, giou: 0.3110)
# Epoch [30] Batch [90/156] Loss: 0.8158 (cls: 0.0873, bbox: 0.0249, giou: 0.3021)
# Epoch [30] Batch [100/156] Loss: 0.6585 (cls: 0.0278, bbox: 0.0217, giou: 0.2612)
# Epoch [30] Batch [110/156] Loss: 0.7565 (cls: 0.0467, bbox: 0.0161, giou: 0.3147)
# Epoch [30] Batch [120/156] Loss: 0.6910 (cls: 0.0711, bbox: 0.0188, giou: 0.2629)
# Epoch [30] Batch [130/156] Loss: 0.5977 (cls: 0.0109, bbox: 0.0225, giou: 0.2372)
# Epoch [30] Batch [140/156] Loss: 0.6869 (cls: 0.0555, bbox: 0.0201, giou: 0.2654)
# Epoch [30] Batch [150/156] Loss: 0.9189 (cls: 0.1402, bbox: 0.0260, giou: 0.3244)
#
# Epoch [30/50] Train Loss: 0.6928 | Val Loss: 0.7581
#
# Epoch [31] Batch [0/156] Loss: 0.6994 (cls: 0.0338, bbox: 0.0161, giou: 0.2925)
# Epoch [31] Batch [10/156] Loss: 0.7475 (cls: 0.0586, bbox: 0.0191, giou: 0.2966)
# Epoch [31] Batch [20/156] Loss: 0.6997 (cls: 0.0197, bbox: 0.0184, giou: 0.2941)
# Epoch [31] Batch [30/156] Loss: 0.6179 (cls: 0.0364, bbox: 0.0164, giou: 0.2498)
# Epoch [31] Batch [40/156] Loss: 0.8082 (cls: 0.0233, bbox: 0.0247, giou: 0.3307)
# Epoch [31] Batch [50/156] Loss: 0.6564 (cls: 0.0910, bbox: 0.0180, giou: 0.2378)
# Epoch [31] Batch [60/156] Loss: 0.7031 (cls: 0.0613, bbox: 0.0163, giou: 0.2802)
# Epoch [31] Batch [70/156] Loss: 0.5323 (cls: 0.0124, bbox: 0.0170, giou: 0.2175)
# Epoch [31] Batch [80/156] Loss: 0.8140 (cls: 0.0602, bbox: 0.0244, giou: 0.3159)
# Epoch [31] Batch [90/156] Loss: 0.5575 (cls: 0.0126, bbox: 0.0168, giou: 0.2305)
# Epoch [31] Batch [100/156] Loss: 0.7379 (cls: 0.0709, bbox: 0.0181, giou: 0.2882)
# Epoch [31] Batch [110/156] Loss: 0.6908 (cls: 0.0546, bbox: 0.0202, giou: 0.2676)
# Epoch [31] Batch [120/156] Loss: 0.6354 (cls: 0.0426, bbox: 0.0168, giou: 0.2543)
# Epoch [31] Batch [130/156] Loss: 0.6064 (cls: 0.0439, bbox: 0.0175, giou: 0.2374)
# Epoch [31] Batch [140/156] Loss: 0.6650 (cls: 0.0318, bbox: 0.0182, giou: 0.2711)
# Epoch [31] Batch [150/156] Loss: 0.7433 (cls: 0.0362, bbox: 0.0178, giou: 0.3091)
#
# Epoch [31/50] Train Loss: 0.6790 | Val Loss: 0.7558
#
# Epoch [32] Batch [0/156] Loss: 0.7544 (cls: 0.0663, bbox: 0.0236, giou: 0.2850)
# Epoch [32] Batch [10/156] Loss: 0.6852 (cls: 0.0342, bbox: 0.0180, giou: 0.2806)
# Epoch [32] Batch [20/156] Loss: 0.6125 (cls: 0.0291, bbox: 0.0240, giou: 0.2318)
# Epoch [32] Batch [30/156] Loss: 0.5722 (cls: 0.0382, bbox: 0.0210, giou: 0.2146)
# Epoch [32] Batch [40/156] Loss: 0.6793 (cls: 0.0327, bbox: 0.0203, giou: 0.2725)
# Epoch [32] Batch [50/156] Loss: 0.8434 (cls: 0.1108, bbox: 0.0292, giou: 0.2934)
# Epoch [32] Batch [60/156] Loss: 0.7653 (cls: 0.0829, bbox: 0.0187, giou: 0.2946)
# Epoch [32] Batch [70/156] Loss: 0.7148 (cls: 0.1482, bbox: 0.0187, giou: 0.2366)
# Epoch [32] Batch [80/156] Loss: 0.6718 (cls: 0.0451, bbox: 0.0189, giou: 0.2660)
# Epoch [32] Batch [90/156] Loss: 0.6456 (cls: 0.0203, bbox: 0.0205, giou: 0.2615)
# Epoch [32] Batch [100/156] Loss: 0.6993 (cls: 0.0185, bbox: 0.0207, giou: 0.2887)
# Epoch [32] Batch [110/156] Loss: 0.6634 (cls: 0.0127, bbox: 0.0197, giou: 0.2762)
# Epoch [32] Batch [120/156] Loss: 0.6249 (cls: 0.0177, bbox: 0.0177, giou: 0.2595)
# Epoch [32] Batch [130/156] Loss: 0.8460 (cls: 0.1027, bbox: 0.0253, giou: 0.3085)
# Epoch [32] Batch [140/156] Loss: 0.6047 (cls: 0.0178, bbox: 0.0171, giou: 0.2507)
# Epoch [32] Batch [150/156] Loss: 0.8723 (cls: 0.0982, bbox: 0.0251, giou: 0.3242)
#
# Epoch [32/50] Train Loss: 0.6737 | Val Loss: 0.7432
#
#   ✅ Saved best model (val_loss: 0.7432)
# Epoch [33] Batch [0/156] Loss: 0.7604 (cls: 0.0174, bbox: 0.0198, giou: 0.3220)
# Epoch [33] Batch [10/156] Loss: 0.8046 (cls: 0.0779, bbox: 0.0217, giou: 0.3092)
# Epoch [33] Batch [20/156] Loss: 0.6584 (cls: 0.0660, bbox: 0.0160, giou: 0.2562)
# Epoch [33] Batch [30/156] Loss: 0.7236 (cls: 0.1127, bbox: 0.0165, giou: 0.2641)
# Epoch [33] Batch [40/156] Loss: 0.7227 (cls: 0.0654, bbox: 0.0167, giou: 0.2870)
# Epoch [33] Batch [50/156] Loss: 0.7278 (cls: 0.0708, bbox: 0.0182, giou: 0.2831)
# Epoch [33] Batch [60/156] Loss: 0.6235 (cls: 0.0141, bbox: 0.0160, giou: 0.2647)
# Epoch [33] Batch [70/156] Loss: 0.7122 (cls: 0.0744, bbox: 0.0171, giou: 0.2762)
# Epoch [33] Batch [80/156] Loss: 0.7836 (cls: 0.0655, bbox: 0.0150, giou: 0.3216)
# Epoch [33] Batch [90/156] Loss: 0.6129 (cls: 0.0311, bbox: 0.0174, giou: 0.2475)
# Epoch [33] Batch [100/156] Loss: 0.9455 (cls: 0.0952, bbox: 0.0298, giou: 0.3507)
# Epoch [33] Batch [110/156] Loss: 0.6247 (cls: 0.0172, bbox: 0.0153, giou: 0.2656)
# Epoch [33] Batch [120/156] Loss: 0.6123 (cls: 0.0539, bbox: 0.0172, giou: 0.2362)
# Epoch [33] Batch [130/156] Loss: 0.6542 (cls: 0.0324, bbox: 0.0160, giou: 0.2708)
# Epoch [33] Batch [140/156] Loss: 0.6704 (cls: 0.0372, bbox: 0.0179, giou: 0.2720)
# Epoch [33] Batch [150/156] Loss: 0.6254 (cls: 0.0344, bbox: 0.0174, giou: 0.2521)
#
# Epoch [33/50] Train Loss: 0.6655 | Val Loss: 0.7441
#
# Epoch [34] Batch [0/156] Loss: 0.7377 (cls: 0.0213, bbox: 0.0167, giou: 0.3165)
# Epoch [34] Batch [10/156] Loss: 0.7419 (cls: 0.0327, bbox: 0.0180, giou: 0.3096)
# Epoch [34] Batch [20/156] Loss: 0.6673 (cls: 0.0294, bbox: 0.0209, giou: 0.2667)
# Epoch [34] Batch [30/156] Loss: 0.6735 (cls: 0.0383, bbox: 0.0188, giou: 0.2707)
# Epoch [34] Batch [40/156] Loss: 0.5991 (cls: 0.0268, bbox: 0.0164, giou: 0.2452)
# Epoch [34] Batch [50/156] Loss: 0.6194 (cls: 0.0364, bbox: 0.0162, giou: 0.2511)
# Epoch [34] Batch [60/156] Loss: 0.6733 (cls: 0.0758, bbox: 0.0221, giou: 0.2434)
# Epoch [34] Batch [70/156] Loss: 0.7368 (cls: 0.0659, bbox: 0.0201, giou: 0.2852)
# Epoch [34] Batch [80/156] Loss: 0.6546 (cls: 0.0170, bbox: 0.0181, giou: 0.2736)
# Epoch [34] Batch [90/156] Loss: 0.6237 (cls: 0.0514, bbox: 0.0172, giou: 0.2432)
# Epoch [34] Batch [100/156] Loss: 0.5758 (cls: 0.0194, bbox: 0.0133, giou: 0.2450)
# Epoch [34] Batch [110/156] Loss: 0.5902 (cls: 0.0427, bbox: 0.0165, giou: 0.2325)
# Epoch [34] Batch [120/156] Loss: 0.6573 (cls: 0.0665, bbox: 0.0233, giou: 0.2371)
# Epoch [34] Batch [130/156] Loss: 0.7066 (cls: 0.0584, bbox: 0.0173, giou: 0.2808)
# Epoch [34] Batch [140/156] Loss: 0.5458 (cls: 0.0461, bbox: 0.0148, giou: 0.2128)
# Epoch [34] Batch [150/156] Loss: 0.6141 (cls: 0.0351, bbox: 0.0148, giou: 0.2525)
#
# Epoch [34/50] Train Loss: 0.6579 | Val Loss: 0.7173
#
#   ✅ Saved best model (val_loss: 0.7173)
# Epoch [35] Batch [0/156] Loss: 0.5901 (cls: 0.0252, bbox: 0.0158, giou: 0.2430)
# Epoch [35] Batch [10/156] Loss: 0.6183 (cls: 0.0673, bbox: 0.0151, giou: 0.2378)
# Epoch [35] Batch [20/156] Loss: 0.5822 (cls: 0.0363, bbox: 0.0177, giou: 0.2287)
# Epoch [35] Batch [30/156] Loss: 0.6120 (cls: 0.0226, bbox: 0.0193, giou: 0.2464)
# Epoch [35] Batch [40/156] Loss: 0.6571 (cls: 0.0430, bbox: 0.0143, giou: 0.2713)
# Epoch [35] Batch [50/156] Loss: 0.7254 (cls: 0.0836, bbox: 0.0170, giou: 0.2785)
# Epoch [35] Batch [60/156] Loss: 0.6547 (cls: 0.0608, bbox: 0.0163, giou: 0.2563)
# Epoch [35] Batch [70/156] Loss: 0.7195 (cls: 0.0420, bbox: 0.0195, giou: 0.2899)
# Epoch [35] Batch [80/156] Loss: 0.6992 (cls: 0.0472, bbox: 0.0254, giou: 0.2625)
# Epoch [35] Batch [90/156] Loss: 0.6356 (cls: 0.0382, bbox: 0.0191, giou: 0.2510)
# Epoch [35] Batch [100/156] Loss: 0.6786 (cls: 0.0673, bbox: 0.0193, giou: 0.2574)
# Epoch [35] Batch [110/156] Loss: 0.7790 (cls: 0.0630, bbox: 0.0171, giou: 0.3153)
# Epoch [35] Batch [120/156] Loss: 0.6495 (cls: 0.0570, bbox: 0.0163, giou: 0.2556)
# Epoch [35] Batch [130/156] Loss: 0.7458 (cls: 0.0876, bbox: 0.0197, giou: 0.2799)
# Epoch [35] Batch [140/156] Loss: 0.6128 (cls: 0.0271, bbox: 0.0145, giou: 0.2567)
# Epoch [35] Batch [150/156] Loss: 0.6940 (cls: 0.0660, bbox: 0.0177, giou: 0.2698)
#
# Epoch [35/50] Train Loss: 0.6455 | Val Loss: 0.7047
#
#   ✅ Saved best model (val_loss: 0.7047)
# Epoch [36] Batch [0/156] Loss: 0.5408 (cls: 0.0384, bbox: 0.0208, giou: 0.1993)
# ...
# Epoch [39] Batch [70/156] Loss: 0.5092 (cls: 0.0371, bbox: 0.0130, giou: 0.2035)
# Epoch [39] Batch [80/156] Loss: 0.5497 (cls: 0.0164, bbox: 0.0212, giou: 0.2136)
# Epoch [39] Batch [90/156] Loss: 0.7034 (cls: 0.0579, bbox: 0.0177, giou: 0.2786)
# Epoch [39] Batch [100/156] Loss: 0.6990 (cls: 0.0705, bbox: 0.0206, giou: 0.2628)
# Epoch [39] Batch [110/156] Loss: 0.5200 (cls: 0.0278, bbox: 0.0162, giou: 0.2056)
# Epoch [39] Batch [120/156] Loss: 0.6246 (cls: 0.0343, bbox: 0.0148, giou: 0.2581)
# Epoch [39] Batch [130/156] Loss: 0.5029 (cls: 0.0318, bbox: 0.0145, giou: 0.1993)
# Epoch [39] Batch [140/156] Loss: 0.7629 (cls: 0.0831, bbox: 0.0178, giou: 0.2955)
# Epoch [39] Batch [150/156] Loss: 0.6350 (cls: 0.0668, bbox: 0.0148, giou: 0.2470)
#
# Epoch [39/50] Train Loss: 0.6210 | Val Loss: 0.6985
#
#   ✅ Saved best model (val_loss: 0.6985)
# Epoch [40] Batch [0/156] Loss: 0.6174 (cls: 0.1082, bbox: 0.0143, giou: 0.2189)
# Epoch [40] Batch [10/156] Loss: 0.5784 (cls: 0.0218, bbox: 0.0169, giou: 0.2361)
# Epoch [40] Batch [20/156] Loss: 0.6659 (cls: 0.0385, bbox: 0.0242, giou: 0.2533)
# Epoch [40] Batch [30/156] Loss: 0.4841 (cls: 0.0221, bbox: 0.0150, giou: 0.1935)
# Epoch [40] Batch [40/156] Loss: 0.5652 (cls: 0.0323, bbox: 0.0168, giou: 0.2243)
# Epoch [40] Batch [50/156] Loss: 0.6780 (cls: 0.0248, bbox: 0.0169, giou: 0.2844)
# Epoch [40] Batch [60/156] Loss: 0.6486 (cls: 0.0407, bbox: 0.0160, giou: 0.2640)
# Epoch [40] Batch [70/156] Loss: 0.7007 (cls: 0.0679, bbox: 0.0175, giou: 0.2727)
# Epoch [40] Batch [80/156] Loss: 0.6134 (cls: 0.0265, bbox: 0.0170, giou: 0.2510)
# Epoch [40] Batch [90/156] Loss: 0.5306 (cls: 0.0153, bbox: 0.0149, giou: 0.2203)
# Epoch [40] Batch [100/156] Loss: 0.5433 (cls: 0.0147, bbox: 0.0208, giou: 0.2122)
# Epoch [40] Batch [110/156] Loss: 0.5740 (cls: 0.0327, bbox: 0.0159, giou: 0.2309)
# Epoch [40] Batch [120/156] Loss: 0.4790 (cls: 0.0104, bbox: 0.0155, giou: 0.1956)
# Epoch [40] Batch [130/156] Loss: 0.6461 (cls: 0.0474, bbox: 0.0152, giou: 0.2614)
# Epoch [40] Batch [140/156] Loss: 0.5808 (cls: 0.0370, bbox: 0.0152, giou: 0.2340)
# Epoch [40] Batch [150/156] Loss: 0.5496 (cls: 0.0453, bbox: 0.0158, giou: 0.2125)
#
# Epoch [40/50] Train Loss: 0.6078 | Val Loss: 0.6938
#
#   ✅ Saved best model (val_loss: 0.6938)
# Epoch [41] Batch [0/156] Loss: 0.6833 (cls: 0.0165, bbox: 0.0128, giou: 0.3013)
# Epoch [41] Batch [10/156] Loss: 0.6334 (cls: 0.0559, bbox: 0.0246, giou: 0.2273)
# Epoch [41] Batch [20/156] Loss: 0.6042 (cls: 0.0622, bbox: 0.0188, giou: 0.2240)
# Epoch [41] Batch [30/156] Loss: 0.6546 (cls: 0.0333, bbox: 0.0189, giou: 0.2634)
# Epoch [41] Batch [40/156] Loss: 0.6219 (cls: 0.0525, bbox: 0.0163, giou: 0.2439)
# Epoch [41] Batch [50/156] Loss: 0.4802 (cls: 0.0203, bbox: 0.0158, giou: 0.1904)
# Epoch [41] Batch [60/156] Loss: 0.5337 (cls: 0.0473, bbox: 0.0146, giou: 0.2068)
# Epoch [41] Batch [70/156] Loss: 0.6669 (cls: 0.0362, bbox: 0.0152, giou: 0.2775)
# Epoch [41] Batch [80/156] Loss: 0.5935 (cls: 0.0514, bbox: 0.0155, giou: 0.2323)
# Epoch [41] Batch [90/156] Loss: 0.5573 (cls: 0.0592, bbox: 0.0127, giou: 0.2172)
# Epoch [41] Batch [100/156] Loss: 0.5083 (cls: 0.0103, bbox: 0.0194, giou: 0.2006)
# Epoch [41] Batch [110/156] Loss: 0.6518 (cls: 0.0169, bbox: 0.0157, giou: 0.2781)
# Epoch [41] Batch [120/156] Loss: 0.5367 (cls: 0.0485, bbox: 0.0139, giou: 0.2093)
# Epoch [41] Batch [130/156] Loss: 0.5014 (cls: 0.0617, bbox: 0.0136, giou: 0.1858)
# Epoch [41] Batch [140/156] Loss: 0.6184 (cls: 0.0528, bbox: 0.0174, giou: 0.2394)
# Epoch [41] Batch [150/156] Loss: 0.6887 (cls: 0.0471, bbox: 0.0186, giou: 0.2744)
#
# Epoch [41/50] Train Loss: 0.6027 | Val Loss: 0.6872
#
#   ✅ Saved best model (val_loss: 0.6872)
# Epoch [42] Batch [0/156] Loss: 0.5943 (cls: 0.0440, bbox: 0.0148, giou: 0.2381)
# Epoch [42] Batch [10/156] Loss: 0.6677 (cls: 0.0474, bbox: 0.0170, giou: 0.2676)
# Epoch [42] Batch [20/156] Loss: 0.5564 (cls: 0.0156, bbox: 0.0143, giou: 0.2345)
# Epoch [42] Batch [30/156] Loss: 0.5274 (cls: 0.0219, bbox: 0.0152, giou: 0.2148)
# Epoch [42] Batch [40/156] Loss: 0.5777 (cls: 0.0531, bbox: 0.0143, giou: 0.2267)
# Epoch [42] Batch [50/156] Loss: 0.5854 (cls: 0.0498, bbox: 0.0172, giou: 0.2247)
# Epoch [42] Batch [60/156] Loss: 0.6737 (cls: 0.0641, bbox: 0.0175, giou: 0.2609)
# Epoch [42] Batch [70/156] Loss: 0.6338 (cls: 0.0510, bbox: 0.0176, giou: 0.2474)
# Epoch [42] Batch [80/156] Loss: 0.5319 (cls: 0.0147, bbox: 0.0144, giou: 0.2226)
# Epoch [42] Batch [90/156] Loss: 0.6249 (cls: 0.0397, bbox: 0.0184, giou: 0.2465)
# Epoch [42] Batch [100/156] Loss: 0.5820 (cls: 0.0410, bbox: 0.0160, giou: 0.2304)
# Epoch [42] Batch [110/156] Loss: 0.5471 (cls: 0.0241, bbox: 0.0162, giou: 0.2211)
# Epoch [42] Batch [120/156] Loss: 0.6867 (cls: 0.0792, bbox: 0.0215, giou: 0.2501)
# Epoch [42] Batch [130/156] Loss: 0.5484 (cls: 0.0555, bbox: 0.0154, giou: 0.2079)
# Epoch [42] Batch [140/156] Loss: 0.6271 (cls: 0.0559, bbox: 0.0202, giou: 0.2350)
# Epoch [42] Batch [150/156] Loss: 0.5032 (cls: 0.0149, bbox: 0.0141, giou: 0.2089)
#
# Epoch [42/50] Train Loss: 0.6003 | Val Loss: 0.6911
#
# Epoch [43] Batch [0/156] Loss: 0.5185 (cls: 0.0545, bbox: 0.0185, giou: 0.1858)
# Epoch [43] Batch [10/156] Loss: 0.6491 (cls: 0.0291, bbox: 0.0174, giou: 0.2666)
# Epoch [43] Batch [20/156] Loss: 0.5713 (cls: 0.0232, bbox: 0.0153, giou: 0.2357)
# Epoch [43] Batch [30/156] Loss: 0.6541 (cls: 0.0460, bbox: 0.0150, giou: 0.2664)
# Epoch [43] Batch [40/156] Loss: 0.7486 (cls: 0.0296, bbox: 0.0276, giou: 0.2904)
# Epoch [43] Batch [50/156] Loss: 0.6391 (cls: 0.0380, bbox: 0.0162, giou: 0.2600)
# Epoch [43] Batch [60/156] Loss: 0.7672 (cls: 0.0351, bbox: 0.0206, giou: 0.3146)
# Epoch [43] Batch [70/156] Loss: 0.5370 (cls: 0.0361, bbox: 0.0135, giou: 0.2168)
# Epoch [43] Batch [80/156] Loss: 0.6305 (cls: 0.0523, bbox: 0.0143, giou: 0.2533)
# Epoch [43] Batch [90/156] Loss: 0.6038 (cls: 0.0235, bbox: 0.0125, giou: 0.2590)
# Epoch [43] Batch [100/156] Loss: 0.5262 (cls: 0.0553, bbox: 0.0117, giou: 0.2063)
# Epoch [43] Batch [110/156] Loss: 0.7513 (cls: 0.0633, bbox: 0.0236, giou: 0.2848)
# Epoch [43] Batch [120/156] Loss: 0.6921 (cls: 0.0450, bbox: 0.0192, giou: 0.2756)
# Epoch [43] Batch [130/156] Loss: 0.5756 (cls: 0.0255, bbox: 0.0156, giou: 0.2360)
# Epoch [43] Batch [140/156] Loss: 0.6551 (cls: 0.0562, bbox: 0.0151, giou: 0.2616)
# Epoch [43] Batch [150/156] Loss: 0.5585 (cls: 0.0266, bbox: 0.0168, giou: 0.2238)
#
# Epoch [43/50] Train Loss: 0.5975 | Val Loss: 0.6856
#
#   ✅ Saved best model (val_loss: 0.6856)
# Epoch [44] Batch [0/156] Loss: 0.5873 (cls: 0.0652, bbox: 0.0171, giou: 0.2183)
# Epoch [44] Batch [10/156] Loss: 0.6385 (cls: 0.0870, bbox: 0.0159, giou: 0.2359)
# Epoch [44] Batch [20/156] Loss: 0.5251 (cls: 0.0285, bbox: 0.0138, giou: 0.2139)
# Epoch [44] Batch [30/156] Loss: 0.5651 (cls: 0.0712, bbox: 0.0176, giou: 0.2028)
# Epoch [44] Batch [40/156] Loss: 0.5755 (cls: 0.0521, bbox: 0.0128, giou: 0.2297)
# Epoch [44] Batch [50/156] Loss: 0.6223 (cls: 0.0198, bbox: 0.0166, giou: 0.2597)
# Epoch [44] Batch [60/156] Loss: 0.7161 (cls: 0.0884, bbox: 0.0162, giou: 0.2734)
# Epoch [44] Batch [70/156] Loss: 0.6041 (cls: 0.0458, bbox: 0.0186, giou: 0.2327)
# Epoch [44] Batch [80/156] Loss: 0.6651 (cls: 0.0382, bbox: 0.0171, giou: 0.2707)
# Epoch [44] Batch [90/156] Loss: 0.5316 (cls: 0.0115, bbox: 0.0151, giou: 0.2223)
# Epoch [44] Batch [100/156] Loss: 0.5591 (cls: 0.0331, bbox: 0.0155, giou: 0.2242)
# Epoch [44] Batch [110/156] Loss: 0.6635 (cls: 0.0384, bbox: 0.0160, giou: 0.2726)
# Epoch [44] Batch [120/156] Loss: 0.5614 (cls: 0.0224, bbox: 0.0153, giou: 0.2311)
# Epoch [44] Batch [130/156] Loss: 0.6011 (cls: 0.0379, bbox: 0.0206, giou: 0.2301)
# Epoch [44] Batch [140/156] Loss: 0.5060 (cls: 0.0422, bbox: 0.0159, giou: 0.1921)
# Epoch [44] Batch [150/156] Loss: 0.6128 (cls: 0.0442, bbox: 0.0180, giou: 0.2392)
#
# Epoch [44/50] Train Loss: 0.5913 | Val Loss: 0.6837
#
#   ✅ Saved best model (val_loss: 0.6837)
# Epoch [45] Batch [0/156] Loss: 0.5523 (cls: 0.0485, bbox: 0.0158, giou: 0.2125)
# Epoch [45] Batch [10/156] Loss: 0.5806 (cls: 0.0340, bbox: 0.0141, giou: 0.2380)
# Epoch [45] Batch [20/156] Loss: 0.6058 (cls: 0.0172, bbox: 0.0168, giou: 0.2522)
# Epoch [45] Batch [30/156] Loss: 0.5280 (cls: 0.0449, bbox: 0.0164, giou: 0.2004)
# Epoch [45] Batch [40/156] Loss: 0.5688 (cls: 0.0536, bbox: 0.0131, giou: 0.2248)
# Epoch [45] Batch [50/156] Loss: 0.5310 (cls: 0.0420, bbox: 0.0170, giou: 0.2020)
# Epoch [45] Batch [60/156] Loss: 0.5934 (cls: 0.0362, bbox: 0.0146, giou: 0.2421)
# Epoch [45] Batch [70/156] Loss: 0.6683 (cls: 0.0337, bbox: 0.0182, giou: 0.2718)
# Epoch [45] Batch [80/156] Loss: 0.6092 (cls: 0.0181, bbox: 0.0158, giou: 0.2561)
# Epoch [45] Batch [90/156] Loss: 0.5586 (cls: 0.0368, bbox: 0.0155, giou: 0.2222)
# Epoch [45] Batch [100/156] Loss: 0.5822 (cls: 0.0372, bbox: 0.0158, giou: 0.2329)
# Epoch [45] Batch [110/156] Loss: 0.5708 (cls: 0.0518, bbox: 0.0199, giou: 0.2098)
# Epoch [45] Batch [120/156] Loss: 0.5284 (cls: 0.0233, bbox: 0.0162, giou: 0.2120)
# Epoch [45] Batch [130/156] Loss: 0.6785 (cls: 0.0247, bbox: 0.0185, giou: 0.2807)
# Epoch [45] Batch [140/156] Loss: 0.6310 (cls: 0.0834, bbox: 0.0166, giou: 0.2324)
# Epoch [45] Batch [150/156] Loss: 0.5568 (cls: 0.0138, bbox: 0.0134, giou: 0.2380)
#
# Epoch [45/50] Train Loss: 0.5867 | Val Loss: 0.6757
#
#   ✅ Saved best model (val_loss: 0.6757)
# Epoch [46] Batch [0/156] Loss: 0.5953 (cls: 0.0382, bbox: 0.0153, giou: 0.2404)
# Epoch [46] Batch [10/156] Loss: 0.5986 (cls: 0.0500, bbox: 0.0175, giou: 0.2305)
# Epoch [46] Batch [20/156] Loss: 0.6574 (cls: 0.0382, bbox: 0.0178, giou: 0.2650)
# Epoch [46] Batch [30/156] Loss: 0.4767 (cls: 0.0237, bbox: 0.0126, giou: 0.1951)
# Epoch [46] Batch [40/156] Loss: 0.6308 (cls: 0.0487, bbox: 0.0165, giou: 0.2499)
# Epoch [46] Batch [50/156] Loss: 0.5277 (cls: 0.0537, bbox: 0.0124, giou: 0.2060)
# Epoch [46] Batch [60/156] Loss: 0.7328 (cls: 0.1011, bbox: 0.0188, giou: 0.2690)
# Epoch [46] Batch [70/156] Loss: 0.5941 (cls: 0.0587, bbox: 0.0137, giou: 0.2333)
# Epoch [46] Batch [80/156] Loss: 0.5726 (cls: 0.0164, bbox: 0.0155, giou: 0.2393)
# Epoch [46] Batch [90/156] Loss: 0.6359 (cls: 0.0358, bbox: 0.0156, giou: 0.2609)
# Epoch [46] Batch [100/156] Loss: 0.5322 (cls: 0.0459, bbox: 0.0155, giou: 0.2043)
# Epoch [46] Batch [110/156] Loss: 0.5952 (cls: 0.0210, bbox: 0.0158, giou: 0.2476)
# Epoch [46] Batch [120/156] Loss: 0.6555 (cls: 0.0838, bbox: 0.0168, giou: 0.2439)
# Epoch [46] Batch [130/156] Loss: 0.5490 (cls: 0.0200, bbox: 0.0147, giou: 0.2278)
# Epoch [46] Batch [140/156] Loss: 0.6266 (cls: 0.0754, bbox: 0.0149, giou: 0.2382)
# Epoch [46] Batch [150/156] Loss: 0.5352 (cls: 0.0388, bbox: 0.0167, giou: 0.2065)
#
# Epoch [46/50] Train Loss: 0.5893 | Val Loss: 0.6752
#
#   ✅ Saved best model (val_loss: 0.6752)
# Epoch [47] Batch [0/156] Loss: 0.5051 (cls: 0.0272, bbox: 0.0133, giou: 0.2057)
# Epoch [47] Batch [10/156] Loss: 0.4901 (cls: 0.0263, bbox: 0.0117, giou: 0.2027)
# Epoch [47] Batch [20/156] Loss: 0.5941 (cls: 0.0270, bbox: 0.0179, giou: 0.2389)
# Epoch [47] Batch [30/156] Loss: 0.6639 (cls: 0.0244, bbox: 0.0158, giou: 0.2803)
# Epoch [47] Batch [40/156] Loss: 0.7331 (cls: 0.1146, bbox: 0.0177, giou: 0.2651)
# Epoch [47] Batch [50/156] Loss: 0.5946 (cls: 0.0567, bbox: 0.0143, giou: 0.2333)
# Epoch [47] Batch [60/156] Loss: 0.5951 (cls: 0.0358, bbox: 0.0162, giou: 0.2392)
# Epoch [47] Batch [70/156] Loss: 0.6379 (cls: 0.0382, bbox: 0.0212, giou: 0.2468)
# Epoch [47] Batch [80/156] Loss: 0.5934 (cls: 0.0354, bbox: 0.0139, giou: 0.2442)
# Epoch [47] Batch [90/156] Loss: 0.5754 (cls: 0.0601, bbox: 0.0153, giou: 0.2193)
# Epoch [47] Batch [100/156] Loss: 0.6359 (cls: 0.0696, bbox: 0.0142, giou: 0.2476)
# Epoch [47] Batch [110/156] Loss: 0.6913 (cls: 0.0996, bbox: 0.0194, giou: 0.2473)
# Epoch [47] Batch [120/156] Loss: 0.5264 (cls: 0.0382, bbox: 0.0138, giou: 0.2097)
# Epoch [47] Batch [130/156] Loss: 0.5362 (cls: 0.0798, bbox: 0.0143, giou: 0.1926)
# Epoch [47] Batch [140/156] Loss: 0.4975 (cls: 0.0165, bbox: 0.0151, giou: 0.2027)
# Epoch [47] Batch [150/156] Loss: 0.6879 (cls: 0.0693, bbox: 0.0191, giou: 0.2614)
#
# Epoch [47/50] Train Loss: 0.5852 | Val Loss: 0.6817
#
# Epoch [48] Batch [0/156] Loss: 0.5498 (cls: 0.0707, bbox: 0.0147, giou: 0.2029)
# Epoch [48] Batch [10/156] Loss: 0.5716 (cls: 0.0309, bbox: 0.0152, giou: 0.2323)
# Epoch [48] Batch [20/156] Loss: 0.5742 (cls: 0.0460, bbox: 0.0112, giou: 0.2360)
# Epoch [48] Batch [30/156] Loss: 0.6438 (cls: 0.0801, bbox: 0.0160, giou: 0.2417)
# Epoch [48] Batch [40/156] Loss: 0.6456 (cls: 0.0198, bbox: 0.0185, giou: 0.2667)
# Epoch [48] Batch [50/156] Loss: 0.5036 (cls: 0.0330, bbox: 0.0160, giou: 0.1952)
# Epoch [48] Batch [60/156] Loss: 0.6696 (cls: 0.0224, bbox: 0.0159, giou: 0.2838)
# Epoch [48] Batch [70/156] Loss: 0.5967 (cls: 0.0272, bbox: 0.0146, giou: 0.2482)
# Epoch [48] Batch [80/156] Loss: 0.5944 (cls: 0.0166, bbox: 0.0148, giou: 0.2520)
# Epoch [48] Batch [90/156] Loss: 0.6243 (cls: 0.0533, bbox: 0.0146, giou: 0.2490)
# Epoch [48] Batch [100/156] Loss: 0.7719 (cls: 0.0634, bbox: 0.0231, giou: 0.2964)
# Epoch [48] Batch [110/156] Loss: 0.6336 (cls: 0.0745, bbox: 0.0135, giou: 0.2458)
# Epoch [48] Batch [120/156] Loss: 0.5585 (cls: 0.0356, bbox: 0.0142, giou: 0.2259)
# Epoch [48] Batch [130/156] Loss: 0.6529 (cls: 0.0168, bbox: 0.0257, giou: 0.2539)
# Epoch [48] Batch [140/156] Loss: 0.4672 (cls: 0.0582, bbox: 0.0120, giou: 0.1746)
# Epoch [48] Batch [150/156] Loss: 0.5683 (cls: 0.0107, bbox: 0.0152, giou: 0.2408)
#
# Epoch [48/50] Train Loss: 0.5786 | Val Loss: 0.6767
#
# Epoch [49] Batch [0/156] Loss: 0.6347 (cls: 0.0349, bbox: 0.0143, giou: 0.2641)
# Epoch [49] Batch [10/156] Loss: 0.5585 (cls: 0.0169, bbox: 0.0146, giou: 0.2344)
# Epoch [49] Batch [20/156] Loss: 0.4796 (cls: 0.0345, bbox: 0.0129, giou: 0.1903)
# Epoch [49] Batch [30/156] Loss: 0.7868 (cls: 0.0595, bbox: 0.0233, giou: 0.3055)
# Epoch [49] Batch [40/156] Loss: 0.5722 (cls: 0.0371, bbox: 0.0135, giou: 0.2339)
# Epoch [49] Batch [50/156] Loss: 0.6254 (cls: 0.0624, bbox: 0.0184, giou: 0.2356)
# Epoch [49] Batch [60/156] Loss: 0.5411 (cls: 0.0473, bbox: 0.0142, giou: 0.2114)
# Epoch [49] Batch [70/156] Loss: 0.6126 (cls: 0.0308, bbox: 0.0165, giou: 0.2495)
# Epoch [49] Batch [80/156] Loss: 0.6987 (cls: 0.0340, bbox: 0.0187, giou: 0.2857)
# Epoch [49] Batch [90/156] Loss: 0.6695 (cls: 0.0320, bbox: 0.0152, giou: 0.2807)
# Epoch [49] Batch [100/156] Loss: 0.4761 (cls: 0.0247, bbox: 0.0123, giou: 0.1949)
# Epoch [49] Batch [110/156] Loss: 0.6518 (cls: 0.0550, bbox: 0.0179, giou: 0.2537)
# Epoch [49] Batch [120/156] Loss: 0.5874 (cls: 0.0300, bbox: 0.0153, giou: 0.2404)
# Epoch [49] Batch [130/156] Loss: 0.5797 (cls: 0.0371, bbox: 0.0154, giou: 0.2328)
# Epoch [49] Batch [140/156] Loss: 0.5774 (cls: 0.0316, bbox: 0.0156, giou: 0.2339)
# Epoch [49] Batch [150/156] Loss: 0.5053 (cls: 0.0183, bbox: 0.0147, giou: 0.2068)
#
# Epoch [49/50] Train Loss: 0.5830 | Val Loss: 0.6759
#
# Epoch [50] Batch [0/156] Loss: 0.5922 (cls: 0.0159, bbox: 0.0152, giou: 0.2502)
# Epoch [50] Batch [10/156] Loss: 0.5308 (cls: 0.0547, bbox: 0.0144, giou: 0.2022)
# Epoch [50] Batch [20/156] Loss: 0.5365 (cls: 0.0113, bbox: 0.0163, giou: 0.2219)
# Epoch [50] Batch [30/156] Loss: 0.5360 (cls: 0.0326, bbox: 0.0133, giou: 0.2185)
# Epoch [50] Batch [40/156] Loss: 0.6124 (cls: 0.0445, bbox: 0.0252, giou: 0.2209)
# Epoch [50] Batch [50/156] Loss: 0.6601 (cls: 0.0442, bbox: 0.0184, giou: 0.2619)
# Epoch [50] Batch [60/156] Loss: 0.5280 (cls: 0.0505, bbox: 0.0167, giou: 0.1969)
# Epoch [50] Batch [70/156] Loss: 0.5763 (cls: 0.0276, bbox: 0.0173, giou: 0.2312)
# Epoch [50] Batch [80/156] Loss: 0.6867 (cls: 0.0490, bbox: 0.0192, giou: 0.2708)
# Epoch [50] Batch [90/156] Loss: 0.5548 (cls: 0.0266, bbox: 0.0154, giou: 0.2256)
# Epoch [50] Batch [100/156] Loss: 0.4217 (cls: 0.0330, bbox: 0.0132, giou: 0.1613)
# Epoch [50] Batch [110/156] Loss: 0.5667 (cls: 0.0526, bbox: 0.0187, giou: 0.2104)
# Epoch [50] Batch [120/156] Loss: 0.5047 (cls: 0.0338, bbox: 0.0160, giou: 0.1953)
# Epoch [50] Batch [130/156] Loss: 0.5139 (cls: 0.0723, bbox: 0.0137, giou: 0.1866)
# Epoch [50] Batch [140/156] Loss: 0.6476 (cls: 0.0449, bbox: 0.0173, giou: 0.2581)
# Epoch [50] Batch [150/156] Loss: 0.6450 (cls: 0.0674, bbox: 0.0162, giou: 0.2483)
#
# Epoch [50/50] Train Loss: 0.5787 | Val Loss: 0.6767
#
# Training complete!

# %%
def _cxcywh_to_xyxy_pixels(boxes, orig_size):
    """Convert normalised [cx,cy,w,h] to pixel [x1,y1,x2,y2]."""
    h, w = orig_size[0].item(), orig_size[1].item()
    cx, cy, bw, bh = boxes.unbind(-1)
    x1 = (cx - bw / 2) * w
    y1 = (cy - bh / 2) * h
    x2 = (cx + bw / 2) * w
    y2 = (cy + bh / 2) * h
    return torch.stack([x1, y1, x2, y2], dim=-1)

# %%
from torchmetrics.detection.mean_ap import MeanAveragePrecision

@torch.no_grad()
def evaluate_map(model, dataloader, device):
    model.eval()

    metric = MeanAveragePrecision(
        iou_type="bbox",
        iou_thresholds=[0.5, 0.75],
        max_detection_thresholds=[1, 10, 100]
    )

    for batch in dataloader:
        pixel_values = batch["pixel_values"].to(device)
        pixel_mask   = batch["pixel_mask"].to(device)
        orig_sizes   = torch.stack([
            torch.tensor([t["orig_size"][0], t["orig_size"][1]]) for t in batch["labels"]
        ]).to(device)

        outputs = model(pixel_values=pixel_values, pixel_mask=pixel_mask)

        # Post-process converts normalised [cx,cy,w,h] → [x1,y1,x2,y2] in pixel coords
        results = processor.post_process_object_detection(
            outputs,
            threshold=0,
            target_sizes=orig_sizes
        )

        preds = [{
            "boxes":  r["boxes"].cpu(),
            "scores": r["scores"].cpu(),
            "labels": r["labels"].cpu(),
        } for r in results]

        gts = [{
            # labels store boxes as normalised cxcywh — convert back to xyxy pixels
            "boxes":  _cxcywh_to_xyxy_pixels(t["boxes"], t["orig_size"]).cpu(),
            "labels": t["class_labels"].cpu(),
        } for t in batch["labels"]]

        metric.update(preds, gts)

    return metric.compute()

# %%
model.load_state_dict(torch.load(f"best_detr_nq{NEW_NUM_QUERIES}.pth", map_location=device))
results = evaluate_map(model, test_loader, device)

# --- 1. Compute F1-Score ---
# Get the overall mAP and the mAR at max 100 detections
map_val = results.get("map", torch.tensor(0.0)).item()
mar_val = results.get("mar_100", torch.tensor(0.0)).item()

# Calculate harmonic mean for F1-score. Add a tiny epsilon (1e-8) to avoid division by zero.
if (map_val + mar_val) > 0:
    f1_score = 2 * (map_val * mar_val) / (map_val + mar_val + 1e-8)
else:
    f1_score = 0.0

# --- 2. Define all metrics to print ---
metrics_to_print = {
    # Precision Metrics
    "mAP@0.50:0.95 (all)"      : "map",
    "mAP@0.50      (all)"      : "map_50",
    "mAP@0.75      (all)"      : "map_75",
    "mAP@0.50:0.95 (small)"    : "map_small",
    "mAP@0.50:0.95 (medium)"   : "map_medium",
    "mAP@0.50:0.95 (large)"    : "map_large",
    
    # Recall Metrics (corresponds to your max_detection_thresholds)
    "mAR@0.50:0.95 (max=1)"    : "mar_1",
    "mAR@0.50:0.95 (max=10)"   : "mar_10",
    "mAR@0.50:0.95 (max=100)"  : "mar_100",
    "mAR@0.50:0.95 (small)"    : "mar_small",
    "mAR@0.50:0.95 (medium)"   : "mar_medium",
    "mAR@0.50:0.95 (large)"    : "mar_large",
}

# --- 3. Print the table ---
print("=" * 45)
print(f"{'Metric':<30} {'Value':>10}")
print("=" * 45)

# Loop through and print mAP and mAR
for label, key in metrics_to_print.items():
    val = results.get(key, torch.tensor(float("nan"))).item()
    print(f"{label:<30} {val:>10.4f}")

print("-" * 45)
# Print the custom F1-score
print(f"{'F1-Score (mAP & mAR@100)':<30} {f1_score:>10.4f}")
print("=" * 45)
# Out:
# =============================================
# Metric                              Value
# =============================================
# mAP@0.50:0.95 (all)                0.5774
# mAP@0.50      (all)                0.8281
# mAP@0.75      (all)                0.3266
# mAP@0.50:0.95 (small)              0.4577
# mAP@0.50:0.95 (medium)             0.7657
# mAP@0.50:0.95 (large)              0.9436
# mAR@0.50:0.95 (max=1)              0.3769
# mAR@0.50:0.95 (max=10)             0.7326
# mAR@0.50:0.95 (max=100)            0.7975
# mAR@0.50:0.95 (small)              0.7421
# mAR@0.50:0.95 (medium)             0.8844
# mAR@0.50:0.95 (large)              0.9778
# ---------------------------------------------
# F1-Score (mAP & mAR@100)           0.6698
# =============================================
